# %%
# Dataset curation notebook

# %%
from rdkit import Chem
from rdkit.Chem import AllChem
from ase.calculators.mopac import MOPAC
from ase.io import read
import pandas as pd
import numpy as np
import time

# %%
dataset = pd.read_csv('../../Data/Solubility/dataset-B.csv')

# %%
#SMILES
smiles = dataset.columns[4]
smiles_list = np.array(dataset[smiles])
print (smiles_list)
#ID
ID = dataset.columns[0]
id_list = np.array(dataset[ID])
print (id_list)

#initialize lists
failures = []
pse_list = []
# Out:
# ['CCC(CC)O[N+]([O-])=O' 'Oc1cc(Br)cc(C=O)c1'
#  '[H+].[Cl-].CCOC(=O)C1(CCN(C)CC1)c2ccccc2' ...
#  'CCc1cccc(CC)c1N(COC)C(=O)CCl' 'CCCCOCN(C(=O)CCl)c1c(CC)cccc1CC'
#  'CCOCN(C(=O)CCl)c1c(C)cccc1CC']
# ['B-1' 'B-2' 'B-3' ... 'B-4648' 'B-4649' 'B-4650']

# %%
def generate():
    
    start = time.time()
    print ('starting...')
    for i,smiles in enumerate(smiles_list):
        try:
    
            #create mol object
            mol = Chem.MolFromSmiles(smiles)
            mol = Chem.AddHs(mol)

            #embed molecule
            AllChem.EmbedMolecule(mol)

            #create xyz file
            fileName = 'xyz/'+id_list[i] + '.xyz'
            Chem.MolToXYZFile(mol,fileName)

            #use ASE to read xyz file
            mol = read(fileName)

            #calculate 
            mol.calc = MOPAC(label='TMP', task = 'UHF BONDS GRADS')

            #get potential energy
            pse = mol.get_potential_energy()

            #save into list
            pse_list.append(pse)
            
            print (id_list[i], ' done')
        except:
            print ('error in ', id_list[i])
            failures.append(smiles)
            continue

        
            
    print ('DONE. time taken = ', time.time()- start)

# %%
generate()
# Out:
# starting...
# B-1  done
# B-2  done
# error in  B-3
# RDKit WARNING: [20:15:43] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [20:15:43] WARNING: not removing hydrogen atom without neighbors
# B-4  done
# B-5  done
# B-6  done
# B-7  done
# B-8  done
# B-9  done
# B-10  done
# B-11  done
# B-12  done
# B-13  done
# B-14  done
# B-15  done
# B-16  done
# B-17  done
# B-18  done
# B-19  done
# B-20  done
# B-21  done
# B-22  done
# B-23  done
# B-24  done
# B-25  done
# B-26  done
# B-27  done
# B-28  done
# B-29  done
# B-30  done
# B-31  done
# B-32  done
# B-33  done
# B-34  done
# B-35  done
# B-36  done
# B-37  done
# B-38  done
# B-39  done
# B-40  done
# B-41  done
# B-42  done
# B-43  done
# B-44  done
# B-45  done
# B-46  done
# B-47  done
# B-48  done
# B-49  done
# B-50  done
# B-51  done
# B-52  done
# B-53  done
# B-54  done
# B-55  done
# B-56  done
# B-57  done
# B-58  done
# B-59  done
# B-60  done
# B-61  done
# B-62  done
# B-63  done
# B-64  done
# B-65  done
# B-66  done
# B-67  done
# B-68  done
# B-69  done
# B-70  done
# B-71  done
# B-72  done
# B-73  done
# B-74  done
# B-75  done
# error in  B-76
# RDKit WARNING: [20:22:18] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [20:22:18] WARNING: not removing hydrogen atom without neighbors
# B-77  done
# B-78  done
# B-79  done
# B-80  done
# B-81  done
# B-82  done
# B-83  done
# B-84  done
# B-85  done
# B-86  done
# B-87  done
# B-88  done
# B-89  done
# B-90  done
# B-91  done
# B-92  done
# B-93  done
# B-94  done
# B-95  done
# B-96  done
# B-97  done
# B-98  done
# B-99  done
# B-100  done
# B-101  done
# B-102  done
# B-103  done
# B-104  done
# B-105  done
# RDKit ERROR: [20:24:26] UFFTYPER: Unrecognized charge state for atom: 4
# B-106  done
# B-107  done
# B-108  done
# B-109  done
# B-110  done
# B-111  done
# B-112  done
# B-113  done
# B-114  done
# error in  B-115
# B-116  done
# B-117  done
# B-118  done
# error in  B-119
# B-120  done
# B-121  done
# error in  B-122
# RDKit WARNING: [20:35:36] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [20:35:36] WARNING: not removing hydrogen atom without neighbors
# B-123  done
# B-124  done
# B-125  done
# B-126  done
# B-127  done
# B-128  done
# B-129  done
# B-130  done
# B-131  done
# B-132  done
# B-133  done
# B-134  done
# B-135  done
# B-136  done
# B-137  done
# B-138  done
# B-139  done
# B-140  done
# B-141  done
# B-142  done
# B-143  done
# B-144  done
# B-145  done
# B-146  done
# B-147  done
# B-148  done
# B-149  done
# B-150  done
# B-151  done
# B-152  done
# B-153  done
# B-154  done
# B-155  done
# B-156  done
# B-157  done
# B-158  done
# B-159  done
# B-160  done
# B-161  done
# B-162  done
# B-163  done
# B-164  done
# B-165  done
# B-166  done
# B-167  done
# B-168  done
# B-169  done
# B-170  done
# B-171  done
# B-172  done
# B-173  done
# B-174  done
# B-175  done
# B-176  done
# B-177  done
# B-178  done
# B-179  done
# B-180  done
# B-181  done
# B-182  done
# B-183  done
# RDKit ERROR: [20:38:39] UFFTYPER: Unrecognized charge state for atom: 1
# B-184  done
# B-185  done
# B-186  done
# B-187  done
# B-188  done
# B-189  done
# B-190  done
# B-191  done
# B-192  done
# B-193  done
# B-194  done
# B-195  done
# B-196  done
# B-197  done
# B-198  done
# B-199  done
# B-200  done
# B-201  done
# B-202  done
# B-203  done
# B-204  done
# B-205  done
# B-206  done
# B-207  done
# B-208  done
# B-209  done
# B-210  done
# B-211  done
# B-212  done
# B-213  done
# B-214  done
# B-215  done
# B-216  done
# B-217  done
# B-218  done
# B-219  done
# B-220  done
# B-221  done
# B-222  done
# B-223  done
# B-224  done
# B-225  done
# B-226  done
# B-227  done
# B-228  done
# B-229  done
# B-230  done
# B-231  done
# B-232  done
# B-233  done
# B-234  done
# B-235  done
# B-236  done
# B-237  done
# B-238  done
# B-239  done
# B-240  done
# B-241  done
# B-242  done
# B-243  done
# B-244  done
# B-245  done
# B-246  done
# B-247  done
# B-248  done
# B-249  done
# B-250  done
# B-251  done
# B-252  done
# B-253  done
# B-254  done
# B-255  done
# B-256  done
# B-257  done
# B-258  done
# B-259  done
# B-260  done
# B-261  done
# B-262  done
# B-263  done
# B-264  done
# B-265  done
# B-266  done
# B-267  done
# B-268  done
# B-269  done
# B-270  done
# B-271  done
# B-272  done
# B-273  done
# B-274  done
# B-275  done
# B-276  done
# B-277  done
# B-278  done
# B-279  done
# B-280  done
# B-281  done
# B-282  done
# B-283  done
# B-284  done
# B-285  done
# B-286  done
# B-287  done
# B-288  done
# B-289  done
# B-290  done
# B-291  done
# B-292  done
# B-293  done
# B-294  done
# B-295  done
# B-296  done
# B-297  done
# B-298  done
# B-299  done
# B-300  done
# B-301  done
# B-302  done
# B-303  done
# B-304  done
# B-305  done
# B-306  done
# B-307  done
# B-308  done
# B-309  done
# B-310  done
# B-311  done
# B-312  done
# B-313  done
# B-314  done
# B-315  done
# B-316  done
# B-317  done
# B-318  done
# B-319  done
# B-320  done
# B-321  done
# B-322  done
# B-323  done
# B-324  done
# B-325  done
# B-326  done
# B-327  done
# B-328  done
# B-329  done
# B-330  done
# B-331  done
# B-332  done
# B-333  done
# B-334  done
# B-335  done
# B-336  done
# B-337  done
# B-338  done
# B-339  done
# B-340  done
# B-341  done
# B-342  done
# B-343  done
# B-344  done
# B-345  done
# B-346  done
# B-347  done
# B-348  done
# B-349  done
# B-350  done
# B-351  done
# B-352  done
# B-353  done
# B-354  done
# B-355  done
# B-356  done
# B-357  done
# B-358  done
# B-359  done
# B-360  done
# B-361  done
# B-362  done
# B-363  done
# B-364  done
# B-365  done
# B-366  done
# B-367  done
# B-368  done
# B-369  done
# B-370  done
# B-371  done
# B-372  done
# B-373  done
# B-374  done
# B-375  done
# B-376  done
# B-377  done
# B-378  done
# B-379  done
# B-380  done
# B-381  done
# B-382  done
# B-383  done
# B-384  done
# B-385  done
# B-386  done
# B-387  done
# B-388  done
# B-389  done
# B-390  done
# B-391  done
# B-392  done
# B-393  done
# B-394  done
# B-395  done
# B-396  done
# B-397  done
# B-398  done
# B-399  done
# B-400  done
# B-401  done
# B-402  done
# B-403  done
# B-404  done
# B-405  done
# B-406  done
# B-407  done
# B-408  done
# B-409  done
# B-410  done
# B-411  done
# B-412  done
# B-413  done
# B-414  done
# B-415  done
# B-416  done
# B-417  done
# B-418  done
# B-419  done
# B-420  done
# B-421  done
# B-422  done
# B-423  done
# B-424  done
# B-425  done
# B-426  done
# B-427  done
# B-428  done
# B-429  done
# B-430  done
# B-431  done
# B-432  done
# B-433  done
# B-434  done
# B-435  done
# B-436  done
# B-437  done
# B-438  done
# B-439  done
# B-440  done
# B-441  done
# B-442  done
# B-443  done
# B-444  done
# B-445  done
# B-446  done
# B-447  done
# B-448  done
# B-449  done
# B-450  done
# B-451  done
# B-452  done
# B-453  done
# B-454  done
# B-455  done
# B-456  done
# B-457  done
# B-458  done
# B-459  done
# B-460  done
# B-461  done
# B-462  done
# B-463  done
# B-464  done
# B-465  done
# B-466  done
# B-467  done
# B-468  done
# B-469  done
# B-470  done
# B-471  done
# B-472  done
# B-473  done
# B-474  done
# B-475  done
# B-476  done
# B-477  done
# B-478  done
# B-479  done
# B-480  done
# B-481  done
# B-482  done
# B-483  done
# B-484  done
# B-485  done
# B-486  done
# B-487  done
# B-488  done
# B-489  done
# B-490  done
# B-491  done
# B-492  done
# B-493  done
# B-494  done
# B-495  done
# B-496  done
# B-497  done
# B-498  done
# B-499  done
# B-500  done
# B-501  done
# B-502  done
# B-503  done
# B-504  done
# B-505  done
# B-506  done
# B-507  done
# B-508  done
# B-509  done
# B-510  done
# B-511  done
# B-512  done
# B-513  done
# B-514  done
# B-515  done
# B-516  done
# B-517  done
# B-518  done
# B-519  done
# B-520  done
# B-521  done
# B-522  done
# B-523  done
# B-524  done
# B-525  done
# B-526  done
# B-527  done
# B-528  done
# B-529  done
# B-530  done
# B-531  done
# B-532  done
# B-533  done
# B-534  done
# B-535  done
# B-536  done
# B-537  done
# B-538  done
# B-539  done
# B-540  done
# B-541  done
# B-542  done
# B-543  done
# B-544  done
# B-545  done
# B-546  done
# B-547  done
# B-548  done
# B-549  done
# B-550  done
# B-551  done
# B-552  done
# B-553  done
# B-554  done
# B-555  done
# B-556  done
# B-557  done
# B-558  done
# B-559  done
# B-560  done
# B-561  done
# B-562  done
# B-563  done
# B-564  done
# B-565  done
# B-566  done
# B-567  done
# B-568  done
# B-569  done
# B-570  done
# B-571  done
# B-572  done
# B-573  done
# B-574  done
# B-575  done
# B-576  done
# B-577  done
# B-578  done
# B-579  done
# B-580  done
# B-581  done
# B-582  done
# B-583  done
# B-584  done
# B-585  done
# B-586  done
# B-587  done
# B-588  done
# B-589  done
# B-590  done
# B-591  done
# B-592  done
# B-593  done
# B-594  done
# B-595  done
# B-596  done
# B-597  done
# B-598  done
# B-599  done
# B-600  done
# B-601  done
# B-602  done
# B-603  done
# B-604  done
# B-605  done
# B-606  done
# B-607  done
# B-608  done
# B-609  done
# B-610  done
# B-611  done
# B-612  done
# B-613  done
# B-614  done
# B-615  done
# B-616  done
# B-617  done
# B-618  done
# B-619  done
# B-620  done
# B-621  done
# B-622  done
# B-623  done
# B-624  done
# B-625  done
# B-626  done
# B-627  done
# B-628  done
# B-629  done
# B-630  done
# B-631  done
# B-632  done
# B-633  done
# B-634  done
# B-635  done
# B-636  done
# B-637  done
# B-638  done
# B-639  done
# B-640  done
# B-641  done
# B-642  done
# B-643  done
# B-644  done
# B-645  done
# B-646  done
# B-647  done
# B-648  done
# B-649  done
# B-650  done
# B-651  done
# B-652  done
# B-653  done
# B-654  done
# B-655  done
# B-656  done
# B-657  done
# B-658  done
# B-659  done
# B-660  done
# B-661  done
# B-662  done
# B-663  done
# B-664  done
# B-665  done
# B-666  done
# B-667  done
# B-668  done
# B-669  done
# B-670  done
# B-671  done
# B-672  done
# B-673  done
# B-674  done
# B-675  done
# B-676  done
# B-677  done
# B-678  done
# B-679  done
# B-680  done
# B-681  done
# B-682  done
# B-683  done
# B-684  done
# B-685  done
# B-686  done
# B-687  done
# B-688  done
# B-689  done
# B-690  done
# B-691  done
# B-692  done
# B-693  done
# B-694  done
# B-695  done
# B-696  done
# B-697  done
# B-698  done
# B-699  done
# B-700  done
# B-701  done
# B-702  done
# B-703  done
# B-704  done
# B-705  done
# B-706  done
# B-707  done
# B-708  done
# B-709  done
# B-710  done
# B-711  done
# B-712  done
# B-713  done
# B-714  done
# B-715  done
# B-716  done
# B-717  done
# B-718  done
# B-719  done
# B-720  done
# B-721  done
# B-722  done
# B-723  done
# B-724  done
# B-725  done
# B-726  done
# B-727  done
# B-728  done
# B-729  done
# B-730  done
# B-731  done
# B-732  done
# B-733  done
# B-734  done
# B-735  done
# B-736  done
# B-737  done
# B-738  done
# B-739  done
# B-740  done
# B-741  done
# RDKit ERROR: [21:00:44] UFFTYPER: Unrecognized charge state for atom: 1
# B-742  done
# error in  B-743
# RDKit ERROR: [21:00:44] UFFTYPER: Unrecognized charge state for atom: 2
# B-744  done
# B-745  done
# B-746  done
# B-747  done
# B-748  done
# B-749  done
# B-750  done
# B-751  done
# B-752  done
# B-753  done
# B-754  done
# B-755  done
# B-756  done
# B-757  done
# B-758  done
# B-759  done
# B-760  done
# B-761  done
# RDKit ERROR: [21:04:35] UFFTYPER: Unrecognized atom type: Ag5 (0)
# B-762  done
# B-763  done
# B-764  done
# B-765  done
# B-766  done
# B-767  done
# B-768  done
# B-769  done
# B-770  done
# B-771  done
# B-772  done
# B-773  done
# B-774  done
# B-775  done
# B-776  done
# B-777  done
# B-778  done
# B-779  done
# B-780  done
# B-781  done
# B-782  done
# B-783  done
# B-784  done
# B-785  done
# B-786  done
# B-787  done
# B-788  done
# B-789  done
# B-790  done
# error in  B-791
# RDKit WARNING: [21:05:50] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [21:05:50] WARNING: not removing hydrogen atom without neighbors
# B-792  done
# B-793  done
# B-794  done
# B-795  done
# B-796  done
# B-797  done
# B-798  done
# B-799  done
# B-800  done
# B-801  done
# B-802  done
# B-803  done
# B-804  done
# B-805  done
# B-806  done
# B-807  done
# B-808  done
# B-809  done
# B-810  done
# B-811  done
# B-812  done
# B-813  done
# error in  B-814
# B-815  done
# B-816  done
# B-817  done
# B-818  done
# B-819  done
# B-820  done
# B-821  done
# B-822  done
# B-823  done
# B-824  done
# B-825  done
# B-826  done
# error in  B-827
# error in  B-828
# RDKit WARNING: [21:07:17] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [21:07:17] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [21:07:17] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [21:07:17] WARNING: not removing hydrogen atom without neighbors
# B-829  done
# B-830  done
# B-831  done
# B-832  done
# B-833  done
# B-834  done
# B-835  done
# B-836  done
# error in  B-837
# B-838  done
# RDKit ERROR: [21:07:36] UFFTYPER: Unrecognized charge state for atom: 1
# B-839  done
# B-840  done
# B-841  done
# B-842  done
# B-843  done
# B-844  done
# B-845  done
# B-846  done
# B-847  done
# B-848  done
# B-849  done
# B-850  done
# error in  B-851
# B-852  done
# B-853  done
# B-854  done
# B-884  done
# B-885  done
# B-886  done
# B-887  done
# B-888  done
# B-889  done
# B-890  done
# B-891  done
# B-892  done
# B-893  done
# B-894  done
# B-895  done
# B-896  done
# B-897  done
# B-898  done
# B-899  done
# error in  B-900
# B-901  done
# B-902  done
# B-903  done
# B-904  done
# B-905  done
# B-906  done
# B-907  done
# B-908  done
# B-909  done
# B-910  done
# B-911  done
# B-912  done
# B-913  done
# B-914  done
# B-915  done
# B-916  done
# B-917  done
# B-918  done
# B-919  done
# B-920  done
# B-921  done
# B-922  done
# B-923  done
# B-924  done
# B-925  done
# error in  B-926
# B-927  done
# RDKit WARNING: [21:11:41] UFFTYPER: Warning: hybridization set to SP3 for atom 1
# RDKit ERROR: [21:11:41] UFFTYPER: Unrecognized charge state for atom: 1
# B-928  done
# B-929  done
# B-930  done
# B-931  done
# B-932  done
# B-933  done
# B-934  done
# B-935  done
# B-936  done
# B-937  done
# B-938  done
# B-939  done
# B-940  done
# B-941  done
# B-942  done
# B-943  done
# B-944  done
# B-945  done
# B-946  done
# B-947  done
# B-948  done
# B-949  done
# B-950  done
# B-951  done
# B-952  done
# B-953  done
# B-954  done
# B-955  done
# B-956  done
# B-957  done
# error in  B-958
# B-959  done
# B-960  done
# B-961  done
# B-962  done
# B-963  done
# B-964  done
# B-965  done
# B-966  done
# B-967  done
# B-968  done
# B-969  done
# B-970  done
# B-971  done
# B-972  done
# B-973  done
# B-974  done
# B-975  done
# B-976  done
# B-977  done
# B-978  done
# B-979  done
# B-980  done
# B-981  done
# B-982  done
# B-983  done
# B-984  done
# B-985  done
# B-986  done
# B-987  done
# B-988  done
# B-989  done
# B-990  done
# B-991  done
# B-992  done
# error in  B-993
# B-994  done
# B-995  done
# B-996  done
# B-997  done
# B-998  done
# B-999  done
# B-1000  done
# B-1001  done
# B-1002  done
# B-1003  done
# B-1004  done
# B-1005  done
# B-1006  done
# B-1007  done
# B-1008  done
# B-1009  done
# B-1010  done
# B-1011  done
# B-1012  done
# B-1013  done
# B-1014  done
# B-1015  done
# B-1016  done
# B-1017  done
# B-1018  done
# B-1019  done
# B-1020  done
# B-1021  done
# B-1022  done
# B-1023  done
# B-1024  done
# B-1025  done
# B-1026  done
# B-1027  done
# B-1028  done
# B-1029  done
# B-1030  done
# B-1031  done
# B-1032  done
# B-1033  done
# B-1034  done
# B-1035  done
# B-1036  done
# B-1037  done
# B-1038  done
# B-1039  done
# B-1040  done
# B-1041  done
# B-1042  done
# B-1043  done
# B-1044  done
# B-1045  done
# B-1046  done
# B-1047  done
# B-1048  done
# B-1049  done
# B-1050  done
# B-1051  done
# B-1052  done
# B-1053  done
# B-1054  done
# B-1055  done
# B-1056  done
# B-1057  done
# B-1058  done
# B-1059  done
# B-1060  done
# B-1061  done
# B-1062  done
# B-1063  done
# B-1064  done
# B-1065  done
# B-1066  done
# B-1067  done
# B-1068  done
# B-1069  done
# B-1070  done
# B-1071  done
# B-1072  done
# B-1073  done
# B-1074  done
# B-1075  done
# B-1076  done
# B-1077  done
# error in  B-1078
# RDKit ERROR: [21:11:41] Cannot write molecules with no conformers to XYZ block
# RDKit ERROR: [21:12:48] Cannot write molecules with no conformers to XYZ block
# RDKit ERROR: [21:16:15] Cannot write molecules with no conformers to XYZ block
# RDKit ERROR: [21:21:06] UFFTYPER: Unrecognized atom type: Cu3 (0)
# B-1079  done
# B-1080  done
# B-1081  done
# B-1082  done
# B-1083  done
# B-1084  done
# B-1085  done
# B-1086  done
# B-1087  done
# B-1088  done
# B-1089  done
# B-1090  done
# B-1091  done
# B-1092  done
# B-1093  done
# error in  B-1094
# RDKit WARNING: [21:21:30] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [21:21:30] WARNING: not removing hydrogen atom without neighbors
# B-1095  done
# B-1096  done
# B-1097  done
# B-1098  done
# B-1099  done
# B-1100  done
# B-1101  done
# B-1102  done
# B-1103  done
# B-1104  done
# B-1105  done
# B-1106  done
# B-1107  done
# B-1108  done
# B-1109  done
# B-1110  done
# B-1111  done
# B-1112  done
# B-1113  done
# B-1114  done
# B-1115  done
# B-1116  done
# B-1117  done
# B-1118  done
# B-1119  done
# B-1120  done
# B-1121  done
# B-1122  done
# B-1123  done
# B-1124  done
# B-1125  done
# B-1126  done
# B-1127  done
# B-1128  done
# error in  B-1129
# RDKit ERROR: [21:22:45] UFFTYPER: Unrecognized atom type: Ba (0)
# B-1130  done
# B-1131  done
# B-1132  done
# B-1133  done
# B-1134  done
# B-1135  done
# B-1136  done
# B-1137  done
# B-1138  done
# B-1139  done
# B-1140  done
# B-1141  done
# B-1142  done
# B-1143  done
# error in  B-1144
# RDKit ERROR: [21:22:54] UFFTYPER: Unrecognized atom type: Ba (0)
# B-1145  done
# B-1146  done
# error in  B-1147
# RDKit ERROR: [21:22:56] UFFTYPER: Unrecognized atom type: Sr (0)
# B-1148  done
# B-1149  done
# B-1150  done
# B-1151  done
# B-1152  done
# B-1153  done
# B-1154  done
# B-1155  done
# B-1156  done
# B-1157  done
# B-1158  done
# B-1159  done
# B-1160  done
# B-1161  done
# B-1162  done
# B-1163  done
# B-1164  done
# B-1165  done
# B-1166  done
# B-1167  done
# B-1168  done
# B-1169  done
# B-1170  done
# B-1171  done
# B-1172  done
# B-1173  done
# B-1174  done
# B-1175  done
# B-1176  done
# B-1177  done
# RDKit ERROR: [21:25:08] UFFTYPER: Unrecognized charge state for atom: 0
# RDKit ERROR: [21:25:08] UFFTYPER: Unrecognized atom type: Zn+2 (0)
# B-1178  done
# B-1179  done
# B-1180  done
# B-1181  done
# B-1182  done
# B-1183  done
# B-1184  done
# B-1185  done
# error in  B-1186
# RDKit ERROR: [21:25:30] UFFTYPER: Unrecognized charge state for atom: 0
# RDKit ERROR: [21:25:30] UFFTYPER: Unrecognized atom type: Zn+2 (0)
# B-1187  done
# error in  B-1188
# B-1189  done
# RDKit ERROR: [21:25:30] UFFTYPER: Unrecognized charge state for atom: 0
# RDKit ERROR: [21:25:30] UFFTYPER: Unrecognized atom type: Zn+2 (0)
# B-1190  done
# B-1191  done
# B-1192  done
# B-1193  done
# B-1194  done
# B-1195  done
# B-1196  done
# B-1197  done
# B-1198  done
# B-1199  done
# B-1200  done
# B-1201  done
# B-1202  done
# B-1203  done
# B-1204  done
# B-1205  done
# B-1206  done
# B-1207  done
# B-1208  done
# B-1209  done
# B-1210  done
# B-1211  done
# B-1212  done
# B-1213  done
# B-1214  done
# B-1215  done
# B-1216  done
# B-1217  done
# B-1218  done
# B-1219  done
# B-1220  done
# B-1221  done
# B-1222  done
# B-1223  done
# B-1224  done
# B-1225  done
# B-1226  done
# B-1227  done
# B-1228  done
# B-1229  done
# B-1230  done
# B-1231  done
# B-1232  done
# error in  B-1233
# B-1234  done
# B-1235  done
# B-1236  done
# B-1237  done
# B-1238  done
# B-1239  done
# B-1240  done
# B-1241  done
# B-1242  done
# B-1243  done
# B-1244  done
# B-1245  done
# B-1246  done
# B-1247  done
# B-1248  done
# B-1249  done
# B-1250  done
# B-1251  done
# B-1252  done
# B-1253  done
# B-1254  done
# B-1255  done
# B-1256  done
# B-1257  done
# B-1258  done
# B-1259  done
# B-1260  done
# B-1261  done
# error in  B-1262
# B-1263  done
# B-1264  done
# B-1265  done
# B-1266  done
# B-1267  done
# B-1268  done
# B-1269  done
# B-1270  done
# B-1271  done
# B-1272  done
# B-1273  done
# B-1274  done
# B-1275  done
# B-1276  done
# B-1277  done
# B-1278  done
# B-1279  done
# B-1280  done
# B-1281  done
# B-1282  done
# B-1283  done
# B-1284  done
# B-1285  done
# B-1286  done
# B-1287  done
# B-1288  done
# B-1289  done
# B-1290  done
# B-1291  done
# B-1292  done
# B-1293  done
# B-1294  done
# B-1295  done
# B-1296  done
# B-1297  done
# B-1298  done
# B-1299  done
# B-1300  done
# B-1301  done
# B-1302  done
# B-1303  done
# B-1304  done
# B-1305  done
# B-1306  done
# B-1307  done
# B-1308  done
# B-1309  done
# B-1310  done
# B-1311  done
# B-1312  done
# B-1313  done
# B-1314  done
# B-1315  done
# B-1316  done
# B-1317  done
# B-1318  done
# B-1319  done
# B-1320  done
# B-1321  done
# B-1322  done
# B-1323  done
# B-1324  done
# B-1325  done
# B-1326  done
# B-1327  done
# B-1328  done
# B-1329  done
# B-1330  done
# B-1331  done
# B-1332  done
# B-1333  done
# B-1334  done
# B-1335  done
# B-1336  done
# B-1337  done
# B-1338  done
# B-1339  done
# B-1340  done
# B-1341  done
# B-1342  done
# B-1343  done
# B-1344  done
# B-1345  done
# B-1346  done
# B-1347  done
# B-1348  done
# B-1349  done
# B-1350  done
# B-1351  done
# B-1352  done
# B-1353  done
# B-1354  done
# B-1355  done
# B-1356  done
# B-1357  done
# B-1358  done
# B-1359  done
# B-1360  done
# B-1361  done
# B-1362  done
# B-1363  done
# B-1364  done
# B-1365  done
# B-1366  done
# B-1367  done
# B-1368  done
# B-1369  done
# B-1370  done
# B-1371  done
# B-1372  done
# B-1373  done
# B-1374  done
# B-1375  done
# B-1376  done
# B-1377  done
# B-1378  done
# B-1379  done
# B-1380  done
# B-1381  done
# B-1382  done
# B-1383  done
# B-1384  done
# B-1385  done
# B-1386  done
# B-1387  done
# B-1388  done
# B-1389  done
# B-1390  done
# B-1391  done
# B-1392  done
# B-1393  done
# B-1394  done
# B-1395  done
# B-1396  done
# B-1397  done
# B-1398  done
# B-1399  done
# B-1400  done
# B-1401  done
# B-1402  done
# B-1403  done
# B-1404  done
# B-1405  done
# B-1406  done
# B-1407  done
# B-1408  done
# B-1409  done
# B-1410  done
# B-1411  done
# B-1412  done
# B-1413  done
# B-1414  done
# B-1415  done
# B-1416  done
# B-1417  done
# B-1418  done
# B-1419  done
# B-1420  done
# B-1421  done
# B-1422  done
# B-1423  done
# B-1424  done
# B-1425  done
# B-1426  done
# B-1427  done
# B-1428  done
# B-1429  done
# B-1430  done
# B-1431  done
# B-1432  done
# B-1433  done
# B-1434  done
# B-1435  done
# B-1436  done
# B-1437  done
# B-1438  done
# B-1439  done
# B-1440  done
# B-1441  done
# B-1442  done
# B-1443  done
# B-1444  done
# B-1445  done
# B-1446  done
# B-1447  done
# B-1448  done
# B-1449  done
# B-1450  done
# B-1451  done
# B-1452  done
# B-1453  done
# B-1454  done
# B-1455  done
# B-1456  done
# B-1457  done
# B-1458  done
# B-1459  done
# B-1460  done
# B-1461  done
# B-1462  done
# B-1463  done
# B-1464  done
# B-1465  done
# B-1466  done
# B-1467  done
# B-1468  done
# B-1469  done
# B-1470  done
# B-1471  done
# B-1472  done
# B-1473  done
# B-1474  done
# B-1475  done
# B-1476  done
# B-1477  done
# B-1478  done
# B-1479  done
# B-1480  done
# B-1481  done
# B-1482  done
# B-1483  done
# B-1484  done
# B-1485  done
# B-1486  done
# B-1487  done
# B-1488  done
# B-1489  done
# B-1490  done
# B-1491  done
# B-1492  done
# B-1493  done
# B-1494  done
# B-1495  done
# B-1496  done
# B-1497  done
# B-1498  done
# B-1499  done
# B-1500  done
# B-1501  done
# B-1502  done
# B-1503  done
# B-1504  done
# B-1505  done
# B-1506  done
# B-1507  done
# B-1508  done
# B-1509  done
# B-1510  done
# B-1511  done
# B-1512  done
# B-1513  done
# B-1514  done
# RDKit ERROR: [21:37:31] UFFTYPER: Unrecognized atom type: Ca (0)
# B-1515  done
# B-1516  done
# B-1517  done
# B-1518  done
# B-1519  done
# B-1520  done
# B-1521  done
# B-1522  done
# B-1523  done
# B-1524  done
# B-1525  done
# B-1526  done
# B-1527  done
# B-1528  done
# B-1529  done
# B-1530  done
# error in  B-1531
# B-1532  done
# B-1533  done
# B-1534  done
# B-1535  done
# B-1536  done
# B-1537  done
# B-1538  done
# B-1539  done
# B-1540  done
# B-1541  done
# B-1542  done
# B-1543  done
# B-1544  done
# B-1545  done
# B-1546  done
# B-1547  done
# B-1548  done
# B-1549  done
# B-1550  done
# B-1551  done
# B-1552  done
# B-1553  done
# B-1554  done
# B-1555  done
# B-1556  done
# B-1557  done
# B-1558  done
# B-1559  done
# B-1560  done
# B-1561  done
# B-1562  done
# B-1563  done
# B-1564  done
# B-1565  done
# B-1566  done
# B-1567  done
# B-1568  done
# B-1569  done
# B-1570  done
# B-1571  done
# B-1572  done
# B-1573  done
# B-1574  done
# B-1575  done
# B-1576  done
# B-1577  done
# B-1578  done
# B-1579  done
# B-1580  done
# B-1581  done
# B-1582  done
# B-1583  done
# B-1584  done
# B-1585  done
# B-1586  done
# B-1587  done
# B-1588  done
# B-1589  done
# error in  B-1590
# RDKit WARNING: [21:40:42] UFFTYPER: Warning: hybridization set to SP3 for atom 4
# B-1591  done
# B-1592  done
# B-1593  done
# B-1594  done
# B-1595  done
# B-1596  done
# B-1597  done
# B-1598  done
# B-1599  done
# B-1600  done
# B-1601  done
# B-1602  done
# B-1603  done
# B-1604  done
# B-1605  done
# B-1606  done
# B-1607  done
# B-1608  done
# B-1609  done
# B-1610  done
# B-1611  done
# B-1612  done
# B-1613  done
# B-1614  done
# B-1615  done
# B-1616  done
# B-1617  done
# B-1618  done
# B-1619  done
# B-1620  done
# B-1621  done
# B-1622  done
# B-1623  done
# B-1624  done
# B-1625  done
# B-1626  done
# B-1627  done
# B-1628  done
# B-1629  done
# B-1630  done
# B-1631  done
# B-1632  done
# B-1633  done
# B-1634  done
# B-1635  done
# B-1636  done
# B-1637  done
# B-1638  done
# B-1639  done
# B-1640  done
# B-1641  done
# B-1642  done
# B-1643  done
# B-1644  done
# B-1645  done
# B-1646  done
# B-1647  done
# B-1648  done
# B-1649  done
# B-1650  done
# B-1651  done
# B-1652  done
# B-1653  done
# B-1654  done
# B-1655  done
# B-1656  done
# B-1657  done
# B-1658  done
# B-1659  done
# B-1660  done
# B-1661  done
# B-1662  done
# B-1663  done
# B-1664  done
# B-1665  done
# B-1666  done
# B-1667  done
# B-1668  done
# B-1669  done
# B-1670  done
# B-1671  done
# B-1672  done
# B-1673  done
# B-1674  done
# B-1675  done
# B-1676  done
# B-1677  done
# B-1678  done
# B-1679  done
# B-1680  done
# B-1681  done
# B-1682  done
# B-1683  done
# B-1684  done
# B-1685  done
# B-1686  done
# B-1687  done
# B-1688  done
# B-1689  done
# B-1690  done
# B-1691  done
# B-1692  done
# B-1693  done
# B-1694  done
# B-1695  done
# B-1696  done
# B-1697  done
# B-1698  done
# B-1699  done
# B-1700  done
# B-1701  done
# B-1702  done
# B-1703  done
# B-1704  done
# B-1705  done
# B-1706  done
# B-1707  done
# B-1708  done
# B-1709  done
# B-1710  done
# B-1711  done
# B-1712  done
# B-1713  done
# B-1714  done
# B-1715  done
# B-1716  done
# B-1717  done
# B-1718  done
# B-1719  done
# B-1720  done
# B-1721  done
# B-1722  done
# RDKit WARNING: [21:48:32] UFFTYPER: Warning: hybridization set to SP3 for atom 5
# RDKit ERROR: [21:48:32] UFFTYPER: Unrecognized charge state for atom: 5
# B-1723  done
# B-1724  done
# B-1725  done
# B-1726  done
# B-1727  done
# B-1728  done
# B-1729  done
# B-1730  done
# B-1731  done
# B-1732  done
# B-1733  done
# B-1734  done
# error in  B-1735
# RDKit WARNING: [21:50:03] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [21:50:03] WARNING: not removing hydrogen atom without neighbors
# B-1736  done
# B-1737  done
# B-1738  done
# B-1739  done
# B-1740  done
# B-1741  done
# B-1742  done
# B-1743  done
# B-1744  done
# B-1745  done
# B-1746  done
# B-1747  done
# B-1748  done
# B-1749  done
# B-1750  done
# B-1751  done
# B-1752  done
# B-1753  done
# B-1754  done
# B-1755  done
# B-1756  done
# B-1757  done
# B-1758  done
# B-1759  done
# B-1760  done
# B-1761  done
# B-1762  done
# B-1763  done
# B-1764  done
# B-1765  done
# B-1766  done
# B-1767  done
# B-1768  done
# B-1769  done
# B-1770  done
# B-1771  done
# B-1772  done
# B-1773  done
# B-1774  done
# B-1775  done
# B-1776  done
# B-1777  done
# B-1778  done
# B-1779  done
# B-1780  done
# B-1781  done
# B-1782  done
# B-1783  done
# B-1784  done
# B-1785  done
# B-1786  done
# B-1787  done
# B-1788  done
# B-1789  done
# B-1790  done
# B-1791  done
# B-1792  done
# B-1793  done
# B-1794  done
# B-1795  done
# B-1796  done
# B-1797  done
# B-1798  done
# B-1799  done
# B-1800  done
# B-1801  done
# B-1802  done
# B-1803  done
# B-1804  done
# B-1805  done
# B-1806  done
# B-1807  done
# B-1808  done
# RDKit ERROR: [21:52:40] UFFTYPER: Unrecognized charge state for atom: 1
# B-1809  done
# B-1810  done
# B-1811  done
# B-1812  done
# B-1813  done
# B-1814  done
# B-1815  done
# B-1816  done
# B-1817  done
# B-1818  done
# B-1819  done
# B-1820  done
# B-1821  done
# B-1822  done
# B-1823  done
# B-1824  done
# B-1825  done
# B-1826  done
# B-1827  done
# B-1828  done
# B-1829  done
# B-1830  done
# B-1831  done
# B-1832  done
# B-1833  done
# B-1834  done
# B-1835  done
# B-1836  done
# B-1837  done
# B-1838  done
# B-1839  done
# B-1840  done
# B-1841  done
# B-1842  done
# B-1843  done
# B-1844  done
# B-1845  done
# B-1846  done
# B-1847  done
# B-1848  done
# B-1849  done
# B-1850  done
# B-1851  done
# B-1852  done
# B-1853  done
# B-1854  done
# B-1855  done
# B-1856  done
# B-1857  done
# B-1858  done
# B-1859  done
# B-1860  done
# B-1861  done
# B-1862  done
# B-1863  done
# B-1864  done
# B-1865  done
# B-1866  done
# B-1867  done
# B-1868  done
# B-1869  done
# B-1870  done
# B-1871  done
# B-1872  done
# B-1873  done
# B-1874  done
# B-1875  done
# B-1876  done
# B-1877  done
# B-1878  done
# B-1879  done
# B-1880  done
# B-1881  done
# B-1882  done
# B-1883  done
# B-1884  done
# B-1885  done
# B-1886  done
# B-1887  done
# B-1888  done
# B-1889  done
# B-1890  done
# B-1891  done
# B-1892  done
# B-1893  done
# B-1894  done
# B-1895  done
# B-1896  done
# B-1897  done
# B-1898  done
# B-1899  done
# B-1900  done
# B-1901  done
# B-1902  done
# B-1903  done
# B-1904  done
# B-1905  done
# B-1906  done
# B-1907  done
# B-1908  done
# B-1909  done
# B-1910  done
# B-1911  done
# B-1912  done
# B-1913  done
# B-1914  done
# error in  B-1915
# B-1916  done
# B-1917  done
# B-1918  done
# B-1919  done
# error in  B-1920
# B-1921  done
# B-1922  done
# B-1923  done
# B-1924  done
# B-1925  done
# B-1926  done
# B-1927  done
# B-1928  done
# B-1929  done
# B-1930  done
# B-1931  done
# B-1932  done
# B-1933  done
# B-1934  done
# B-1935  done
# B-1936  done
# B-1937  done
# B-1938  done
# B-1939  done
# B-1940  done
# B-1941  done
# B-1942  done
# B-1943  done
# B-1944  done
# B-1945  done
# B-1946  done
# B-1947  done
# B-1948  done
# B-1949  done
# B-1950  done
# B-1951  done
# B-1952  done
# B-1953  done
# B-1954  done
# B-1955  done
# B-1956  done
# B-1957  done
# B-1958  done
# B-1959  done
# B-1960  done
# B-1961  done
# B-1962  done
# B-1963  done
# B-1964  done
# B-1965  done
# B-1966  done
# B-1967  done
# B-1968  done
# B-1969  done
# B-1970  done
# B-1971  done
# B-1972  done
# B-1973  done
# B-1974  done
# B-1975  done
# B-1976  done
# B-1977  done
# B-1978  done
# B-1979  done
# B-1980  done
# B-1981  done
# B-1982  done
# B-1983  done
# B-1984  done
# B-1985  done
# B-1986  done
# B-1987  done
# B-1988  done
# B-1989  done
# B-1990  done
# B-1991  done
# B-1992  done
# B-1993  done
# B-1994  done
# B-1995  done
# B-1996  done
# B-1997  done
# RDKit ERROR: [22:03:43] UFFTYPER: Unrecognized atom type: Se2+2 (8)
# B-1998  done
# B-1999  done
# B-2000  done
# B-2001  done
# B-2002  done
# B-2003  done
# B-2004  done
# B-2005  done
# B-2006  done
# B-2007  done
# B-2008  done
# B-2009  done
# B-2010  done
# B-2011  done
# B-2012  done
# B-2013  done
# B-2014  done
# B-2015  done
# B-2016  done
# B-2017  done
# B-2018  done
# B-2019  done
# B-2020  done
# B-2021  done
# B-2022  done
# B-2023  done
# B-2024  done
# B-2025  done
# B-2026  done
# B-2027  done
# B-2028  done
# B-2029  done
# B-2030  done
# B-2031  done
# B-2032  done
# B-2033  done
# B-2034  done
# B-2035  done
# B-2036  done
# B-2037  done
# B-2038  done
# B-2039  done
# B-2040  done
# B-2041  done
# B-2042  done
# B-2043  done
# B-2044  done
# B-2045  done
# B-2046  done
# B-2047  done
# B-2048  done
# B-2049  done
# B-2050  done
# B-2051  done
# B-2052  done
# B-2053  done
# B-2054  done
# B-2055  done
# B-2056  done
# B-2057  done
# B-2058  done
# B-2059  done
# B-2060  done
# B-2061  done
# B-2062  done
# B-2063  done
# B-2064  done
# B-2065  done
# B-2066  done
# B-2067  done
# B-2068  done
# B-2069  done
# B-2070  done
# B-2071  done
# B-2072  done
# B-2073  done
# B-2074  done
# B-2075  done
# B-2076  done
# B-2077  done
# B-2078  done
# B-2079  done
# B-2080  done
# B-2081  done
# B-2082  done
# B-2083  done
# B-2084  done
# B-2085  done
# B-2086  done
# B-2087  done
# B-2088  done
# B-2089  done
# B-2090  done
# B-2091  done
# B-2092  done
# B-2093  done
# B-2094  done
# B-2095  done
# B-2096  done
# B-2097  done
# B-2098  done
# B-2099  done
# B-2100  done
# B-2101  done
# B-2102  done
# B-2103  done
# B-2104  done
# B-2105  done
# B-2106  done
# B-2107  done
# B-2108  done
# B-2109  done
# B-2110  done
# B-2111  done
# B-2112  done
# B-2113  done
# B-2114  done
# B-2115  done
# B-2116  done
# B-2117  done
# B-2118  done
# B-2119  done
# B-2120  done
# B-2121  done
# B-2122  done
# B-2123  done
# B-2124  done
# B-2125  done
# B-2126  done
# B-2127  done
# B-2128  done
# B-2129  done
# B-2130  done
# B-2131  done
# B-2132  done
# B-2133  done
# B-2134  done
# B-2135  done
# B-2136  done
# B-2137  done
# B-2138  done
# B-2139  done
# B-2140  done
# B-2141  done
# B-2142  done
# B-2143  done
# B-2144  done
# B-2145  done
# B-2146  done
# B-2147  done
# B-2148  done
# B-2149  done
# B-2150  done
# B-2151  done
# B-2152  done
# B-2153  done
# B-2154  done
# B-2155  done
# B-2156  done
# B-2157  done
# B-2158  done
# B-2159  done
# B-2160  done
# B-2161  done
# B-2162  done
# B-2163  done
# B-2164  done
# B-2165  done
# B-2166  done
# B-2167  done
# B-2168  done
# B-2169  done
# B-2170  done
# B-2171  done
# B-2172  done
# B-2173  done
# B-2174  done
# B-2175  done
# B-2176  done
# B-2177  done
# B-2178  done
# B-2179  done
# B-2180  done
# B-2181  done
# B-2182  done
# B-2183  done
# B-2184  done
# B-2185  done
# B-2186  done
# B-2187  done
# B-2188  done
# B-2189  done
# B-2190  done
# B-2191  done
# B-2192  done
# B-2193  done
# B-2194  done
# B-2195  done
# B-2196  done
# B-2197  done
# B-2198  done
# B-2199  done
# B-2200  done
# B-2201  done
# B-2202  done
# B-2203  done
# B-2204  done
# B-2205  done
# B-2206  done
# B-2207  done
# B-2208  done
# B-2209  done
# B-2210  done
# B-2211  done
# B-2212  done
# B-2213  done
# B-2214  done
# B-2215  done
# B-2216  done
# B-2217  done
# B-2218  done
# B-2219  done
# B-2220  done
# B-2221  done
# B-2222  done
# B-2223  done
# B-2224  done
# B-2225  done
# B-2226  done
# B-2227  done
# B-2228  done
# B-2229  done
# B-2230  done
# B-2231  done
# B-2232  done
# B-2233  done
# B-2234  done
# B-2235  done
# B-2236  done
# B-2237  done
# B-2238  done
# B-2239  done
# B-2240  done
# B-2241  done
# B-2242  done
# B-2243  done
# B-2244  done
# B-2245  done
# B-2246  done
# B-2247  done
# B-2248  done
# B-2249  done
# B-2250  done
# B-2251  done
# B-2252  done
# B-2253  done
# B-2254  done
# B-2255  done
# B-2256  done
# B-2257  done
# B-2258  done
# B-2259  done
# B-2260  done
# B-2261  done
# B-2262  done
# B-2263  done
# B-2264  done
# B-2265  done
# B-2266  done
# B-2267  done
# B-2268  done
# B-2269  done
# B-2270  done
# B-2271  done
# B-2272  done
# B-2273  done
# B-2274  done
# B-2275  done
# B-2276  done
# B-2277  done
# B-2278  done
# B-2279  done
# B-2280  done
# B-2281  done
# B-2282  done
# B-2283  done
# B-2284  done
# B-2285  done
# B-2286  done
# B-2287  done
# B-2288  done
# B-2289  done
# B-2290  done
# B-2291  done
# B-2292  done
# B-2293  done
# B-2294  done
# B-2295  done
# B-2296  done
# B-2297  done
# B-2298  done
# B-2299  done
# B-2300  done
# B-2301  done
# B-2302  done
# B-2303  done
# B-2304  done
# B-2305  done
# B-2306  done
# B-2307  done
# B-2308  done
# B-2309  done
# B-2310  done
# B-2311  done
# B-2312  done
# B-2313  done
# B-2314  done
# B-2315  done
# B-2316  done
# B-2317  done
# B-2318  done
# B-2319  done
# B-2320  done
# error in  B-2321
# B-2322  done
# RDKit WARNING: [22:22:00] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [22:22:00] WARNING: not removing hydrogen atom without neighbors
# B-2323  done
# B-2324  done
# B-2325  done
# B-2326  done
# B-2327  done
# B-2328  done
# B-2329  done
# error in  B-2330
# B-2331  done
# error in  B-2332
# RDKit ERROR: [22:22:32] UFFTYPER: Unrecognized atom type: Cu3 (0)
# RDKit ERROR: [22:22:32] UFFTYPER: Unrecognized charge state for atom: 1
# B-2333  done
# B-2334  done
# B-2335  done
# B-2336  done
# B-2337  done
# B-2338  done
# B-2339  done
# B-2340  done
# B-2341  done
# B-2342  done
# B-2343  done
# B-2344  done
# B-2345  done
# B-2346  done
# B-2347  done
# B-2348  done
# B-2349  done
# B-2350  done
# B-2351  done
# B-2352  done
# B-2353  done
# B-2354  done
# B-2355  done
# B-2356  done
# B-2357  done
# B-2358  done
# B-2359  done
# B-2360  done
# B-2361  done
# B-2362  done
# B-2363  done
# B-2364  done
# B-2365  done
# B-2366  done
# B-2367  done
# B-2368  done
# B-2369  done
# error in  B-2370
# RDKit ERROR: [22:29:38] UFFTYPER: Unrecognized atom type: Mn3 (0)
# B-2371  done
# B-2372  done
# RDKit ERROR: [22:30:31] UFFTYPER: Unrecognized atom type: Ge2 (5)
# RDKit ERROR: [22:30:31] UFFTYPER: Unrecognized atom type: Ge2 (8)
# B-2373  done
# B-2374  done
# B-2375  done
# B-2376  done
# B-2377  done
# B-2378  done
# B-2379  done
# B-2380  done
# B-2381  done
# B-2382  done
# B-2383  done
# B-2384  done
# B-2385  done
# B-2386  done
# B-2387  done
# B-2388  done
# B-2389  done
# B-2390  done
# B-2391  done
# B-2392  done
# B-2393  done
# B-2394  done
# B-2395  done
# B-2396  done
# B-2397  done
# B-2398  done
# B-2399  done
# B-2400  done
# B-2401  done
# B-2402  done
# B-2403  done
# B-2404  done
# B-2405  done
# B-2406  done
# B-2407  done
# B-2408  done
# B-2409  done
# B-2410  done
# B-2411  done
# B-2412  done
# B-2413  done
# B-2414  done
# B-2415  done
# B-2416  done
# B-2417  done
# B-2418  done
# B-2419  done
# B-2420  done
# B-2421  done
# B-2422  done
# B-2423  done
# B-2424  done
# B-2425  done
# B-2426  done
# B-2427  done
# B-2428  done
# B-2429  done
# B-2430  done
# B-2431  done
# B-2432  done
# B-2433  done
# B-2434  done
# B-2435  done
# B-2436  done
# B-2437  done
# B-2438  done
# B-2439  done
# B-2440  done
# B-2441  done
# B-2442  done
# B-2443  done
# B-2444  done
# B-2445  done
# B-2446  done
# B-2447  done
# B-2448  done
# B-2449  done
# B-2450  done
# B-2451  done
# B-2452  done
# B-2453  done
# B-2454  done
# B-2455  done
# B-2456  done
# B-2457  done
# B-2458  done
# B-2459  done
# B-2460  done
# B-2461  done
# B-2462  done
# error in  B-2463
# RDKit ERROR: [22:39:48] UFFTYPER: Unrecognized atom type: Pt3 (0)
# B-2464  done
# B-2465  done
# B-2466  done
# B-2467  done
# B-2468  done
# B-2469  done
# B-2470  done
# RDKit ERROR: [22:40:07] UFFTYPER: Unrecognized charge state for atom: 0
# RDKit ERROR: [22:40:07] UFFTYPER: Unrecognized atom type: Zn+2 (0)
# B-2471  done
# B-2472  done
# B-2473  done
# B-2474  done
# B-2475  done
# B-2476  done
# B-2477  done
# B-2478  done
# B-2479  done
# B-2480  done
# B-2481  done
# B-2482  done
# B-2483  done
# B-2484  done
# B-2485  done
# B-2486  done
# B-2487  done
# B-2488  done
# B-2489  done
# B-2490  done
# B-2491  done
# B-2492  done
# B-2493  done
# B-2494  done
# B-2495  done
# B-2496  done
# B-2497  done
# B-2498  done
# B-2499  done
# B-2500  done
# B-2501  done
# B-2502  done
# B-2503  done
# B-2504  done
# B-2505  done
# B-2506  done
# B-2507  done
# B-2508  done
# B-2509  done
# B-2510  done
# B-2511  done
# B-2512  done
# B-2513  done
# B-2514  done
# B-2515  done
# B-2516  done
# B-2517  done
# B-2518  done
# B-2519  done
# B-2520  done
# B-2521  done
# B-2522  done
# B-2523  done
# B-2524  done
# B-2525  done
# B-2526  done
# B-2527  done
# B-2528  done
# B-2529  done
# B-2530  done
# B-2531  done
# B-2532  done
# B-2533  done
# B-2534  done
# B-2535  done
# B-2536  done
# B-2537  done
# B-2538  done
# B-2539  done
# B-2540  done
# B-2541  done
# B-2542  done
# B-2543  done
# B-2544  done
# B-2545  done
# B-2546  done
# B-2547  done
# B-2548  done
# B-2549  done
# B-2550  done
# B-2551  done
# B-2552  done
# B-2553  done
# B-2554  done
# B-2555  done
# B-2556  done
# B-2557  done
# B-2558  done
# B-2559  done
# B-2560  done
# B-2561  done
# B-2562  done
# B-2563  done
# B-2564  done
# B-2565  done
# B-2566  done
# B-2567  done
# B-2568  done
# B-2569  done
# B-2591  done
# B-2592  done
# B-2593  done
# B-2594  done
# B-2595  done
# B-2596  done
# B-2597  done
# B-2598  done
# B-2599  done
# B-2600  done
# B-2601  done
# B-2602  done
# B-2603  done
# B-2604  done
# B-2605  done
# B-2606  done
# B-2607  done
# B-2608  done
# B-2609  done
# B-2610  done
# B-2611  done
# B-2612  done
# B-2613  done
# B-2614  done
# B-2615  done
# B-2616  done
# B-2617  done
# B-2618  done
# B-2619  done
# B-2620  done
# B-2621  done
# B-2622  done
# B-2623  done
# B-2624  done
# B-2625  done
# B-2626  done
# B-2627  done
# B-2628  done
# B-2629  done
# error in  B-2630
# RDKit WARNING: [22:51:37] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [22:51:37] WARNING: not removing hydrogen atom without neighbors
# B-2631  done
# B-2632  done
# B-2633  done
# B-2634  done
# B-2635  done
# B-2636  done
# B-2637  done
# B-2638  done
# B-2639  done
# B-2640  done
# B-2641  done
# B-2642  done
# B-2643  done
# B-2644  done
# B-2645  done
# B-2646  done
# B-2647  done
# B-2648  done
# B-2649  done
# B-2650  done
# B-2651  done
# B-2652  done
# B-2653  done
# B-2654  done
# B-2655  done
# B-2656  done
# B-2657  done
# B-2658  done
# B-2659  done
# B-2660  done
# B-2661  done
# B-2662  done
# B-2663  done
# B-2664  done
# B-2665  done
# B-2666  done
# B-2667  done
# B-2668  done
# B-2669  done
# B-2670  done
# B-2671  done
# B-2672  done
# B-2673  done
# B-2674  done
# B-2675  done
# B-2676  done
# B-2677  done
# B-2678  done
# B-2679  done
# B-2680  done
# B-2681  done
# B-2682  done
# B-2683  done
# B-2684  done
# B-2685  done
# B-2686  done
# B-2687  done
# B-2688  done
# error in  B-2689
# B-2690  done
# B-2691  done
# B-2692  done
# B-2693  done
# B-2694  done
# B-2695  done
# B-2696  done
# B-2697  done
# B-2698  done
# B-2699  done
# B-2700  done
# B-2701  done
# B-2702  done
# B-2703  done
# B-2704  done
# B-2705  done
# B-2706  done
# B-2707  done
# B-2708  done
# B-2709  done
# B-2710  done
# B-2711  done
# B-2712  done
# B-2713  done
# B-2714  done
# B-2715  done
# B-2716  done
# B-2717  done
# B-2718  done
# B-2719  done
# B-2720  done
# B-2721  done
# B-2722  done
# B-2723  done
# B-2724  done
# B-2725  done
# B-2726  done
# B-2727  done
# B-2728  done
# B-2729  done
# B-2730  done
# B-2731  done
# B-2732  done
# B-2733  done
# B-2734  done
# B-2735  done
# B-2736  done
# B-2737  done
# B-2738  done
# B-2739  done
# B-2740  done
# B-2741  done
# B-2742  done
# B-2743  done
# B-2744  done
# B-2745  done
# B-2746  done
# B-2747  done
# B-2748  done
# B-2749  done
# B-2750  done
# B-2751  done
# B-2752  done
# B-2753  done
# B-2754  done
# B-2755  done
# B-2756  done
# B-2757  done
# B-2758  done
# B-2759  done
# B-2760  done
# B-2761  done
# B-2762  done
# B-2763  done
# B-2764  done
# B-2765  done
# B-2766  done
# B-2767  done
# B-2768  done
# B-2769  done
# B-2770  done
# B-2771  done
# B-2772  done
# B-2773  done
# B-2774  done
# B-2775  done
# B-2776  done
# B-2777  done
# B-2778  done
# B-2779  done
# B-2780  done
# B-2781  done
# B-2782  done
# B-2783  done
# B-2784  done
# B-2785  done
# B-2786  done
# B-2787  done
# B-2788  done
# B-2789  done
# B-2790  done
# B-2791  done
# B-2792  done
# B-2793  done
# B-2794  done
# B-2795  done
# B-2796  done
# B-2797  done
# B-2798  done
# B-2799  done
# B-2800  done
# B-2801  done
# B-2802  done
# B-2803  done
# B-2804  done
# B-2805  done
# B-2806  done
# B-2807  done
# B-2808  done
# B-2809  done
# B-2810  done
# B-2811  done
# B-2812  done
# B-2813  done
# B-2814  done
# B-2815  done
# B-2816  done
# B-2817  done
# B-2818  done
# B-2819  done
# B-2820  done
# B-2821  done
# B-2822  done
# B-2823  done
# B-2824  done
# B-2825  done
# B-2826  done
# B-2827  done
# B-2828  done
# B-2829  done
# B-2830  done
# B-2831  done
# B-2832  done
# B-2833  done
# B-2834  done
# B-2835  done
# B-2836  done
# B-2837  done
# B-2838  done
# B-2839  done
# B-2840  done
# B-2841  done
# B-2842  done
# B-2843  done
# B-2844  done
# B-2845  done
# B-2846  done
# B-2847  done
# B-2848  done
# B-2849  done
# B-2850  done
# B-2851  done
# B-2852  done
# B-2853  done
# B-2854  done
# B-2855  done
# B-2856  done
# B-2857  done
# B-2858  done
# B-2859  done
# B-2860  done
# B-2861  done
# B-2862  done
# B-2863  done
# B-2864  done
# B-2865  done
# B-2866  done
# B-2867  done
# B-2868  done
# B-2869  done
# B-2870  done
# B-2871  done
# B-2872  done
# B-2873  done
# B-2874  done
# B-2875  done
# B-2876  done
# B-2877  done
# B-2878  done
# B-2879  done
# B-2880  done
# B-2881  done
# B-2882  done
# B-2883  done
# B-2884  done
# B-2885  done
# B-2886  done
# B-2887  done
# B-2888  done
# B-2889  done
# B-2890  done
# B-2891  done
# B-2892  done
# B-2893  done
# B-2894  done
# B-2895  done
# B-2896  done
# B-2897  done
# B-2898  done
# B-2899  done
# B-2900  done
# B-2901  done
# B-2902  done
# B-2903  done
# B-2904  done
# B-2905  done
# B-2906  done
# B-2907  done
# B-2908  done
# B-2909  done
# B-2910  done
# B-2911  done
# B-2912  done
# B-2913  done
# B-2914  done
# B-2915  done
# B-2916  done
# B-2917  done
# B-2918  done
# B-2919  done
# B-2927  done
# B-2928  done
# B-2929  done
# B-2930  done
# B-2931  done
# B-2932  done
# B-2933  done
# B-2934  done
# B-2935  done
# B-2936  done
# B-2937  done
# B-2938  done
# B-2939  done
# B-2940  done
# B-2941  done
# B-2942  done
# B-2943  done
# B-2944  done
# B-2945  done
# B-2946  done
# B-2947  done
# B-2948  done
# B-2949  done
# B-2950  done
# B-2951  done
# B-2952  done
# B-2953  done
# B-2954  done
# B-2955  done
# B-2956  done
# B-2957  done
# B-2958  done
# B-2959  done
# B-2960  done
# B-2961  done
# B-2962  done
# B-2963  done
# B-2964  done
# B-2965  done
# B-2966  done
# B-2967  done
# B-2968  done
# B-2969  done
# B-2970  done
# B-2971  done
# B-2972  done
# B-2973  done
# B-2974  done
# B-2975  done
# B-2976  done
# B-2977  done
# B-2978  done
# B-2979  done
# B-2980  done
# B-2981  done
# B-2982  done
# B-2983  done
# B-2984  done
# B-2985  done
# B-2986  done
# B-2987  done
# B-2988  done
# B-2989  done
# B-2990  done
# B-2991  done
# B-2992  done
# B-2993  done
# B-2994  done
# B-2995  done
# B-2996  done
# B-2997  done
# B-2998  done
# B-2999  done
# B-3000  done
# B-3001  done
# B-3002  done
# B-3003  done
# B-3004  done
# B-3005  done
# B-3006  done
# B-3007  done
# B-3008  done
# B-3009  done
# B-3010  done
# B-3011  done
# B-3012  done
# B-3013  done
# B-3014  done
# B-3015  done
# B-3016  done
# B-3017  done
# B-3018  done
# B-3019  done
# B-3020  done
# B-3021  done
# B-3022  done
# B-3023  done
# B-3024  done
# B-3025  done
# B-3026  done
# B-3027  done
# B-3028  done
# B-3029  done
# B-3030  done
# B-3031  done
# B-3032  done
# B-3033  done
# B-3034  done
# B-3035  done
# B-3036  done
# B-3037  done
# B-3038  done
# B-3039  done
# B-3040  done
# B-3041  done
# B-3042  done
# B-3043  done
# B-3044  done
# B-3045  done
# B-3046  done
# B-3047  done
# B-3048  done
# B-3049  done
# B-3050  done
# B-3051  done
# B-3052  done
# B-3053  done
# B-3054  done
# B-3055  done
# B-3056  done
# B-3057  done
# B-3058  done
# B-3059  done
# B-3060  done
# B-3061  done
# B-3062  done
# B-3063  done
# B-3064  done
# B-3065  done
# B-3066  done
# B-3067  done
# B-3068  done
# B-3069  done
# B-3070  done
# B-3071  done
# B-3072  done
# B-3073  done
# B-3074  done
# B-3075  done
# B-3076  done
# B-3077  done
# B-3078  done
# B-3079  done
# B-3080  done
# B-3081  done
# B-3082  done
# B-3083  done
# B-3084  done
# B-3085  done
# B-3086  done
# B-3087  done
# B-3088  done
# B-3089  done
# B-3090  done
# B-3091  done
# B-3092  done
# B-3093  done
# B-3094  done
# B-3095  done
# B-3096  done
# B-3097  done
# B-3098  done
# B-3099  done
# B-3100  done
# B-3101  done
# B-3102  done
# B-3103  done
# B-3104  done
# B-3105  done
# B-3106  done
# B-3107  done
# B-3108  done
# B-3109  done
# B-3110  done
# B-3111  done
# B-3112  done
# B-3113  done
# B-3114  done
# B-3115  done
# B-3116  done
# B-3117  done
# B-3118  done
# B-3119  done
# B-3120  done
# B-3121  done
# B-3122  done
# B-3123  done
# B-3124  done
# B-3125  done
# B-3126  done
# B-3127  done
# B-3128  done
# B-3129  done
# B-3130  done
# B-3131  done
# B-3132  done
# B-3133  done
# B-3134  done
# B-3135  done
# B-3136  done
# B-3137  done
# B-3138  done
# B-3139  done
# B-3140  done
# B-3141  done
# B-3142  done
# B-3143  done
# B-3144  done
# B-3145  done
# B-3146  done
# B-3147  done
# B-3148  done
# B-3149  done
# B-3150  done
# B-3151  done
# B-3152  done
# B-3153  done
# B-3154  done
# B-3155  done
# B-3156  done
# B-3157  done
# B-3158  done
# B-3159  done
# B-3160  done
# B-3161  done
# B-3162  done
# B-3163  done
# B-3164  done
# B-3165  done
# B-3166  done
# B-3167  done
# B-3168  done
# B-3169  done
# B-3170  done
# error in  B-3171
# RDKit WARNING: [23:47:28] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [23:47:28] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [23:47:28] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [23:47:28] WARNING: not removing hydrogen atom without neighbors
# B-3172  done
# B-3173  done
# B-3174  done
# B-3175  done
# B-3176  done
# B-3177  done
# B-3178  done
# B-3179  done
# B-3180  done
# B-3181  done
# B-3182  done
# B-3183  done
# B-3184  done
# B-3185  done
# B-3186  done
# B-3187  done
# B-3188  done
# B-3189  done
# B-3190  done
# B-3191  done
# B-3192  done
# B-3193  done
# B-3194  done
# B-3195  done
# B-3196  done
# B-3197  done
# B-3198  done
# B-3199  done
# B-3200  done
# B-3201  done
# B-3202  done
# B-3203  done
# B-3204  done
# B-3205  done
# B-3206  done
# B-3207  done
# B-3208  done
# B-3209  done
# B-3210  done
# B-3211  done
# B-3212  done
# B-3213  done
# B-3214  done
# B-3215  done
# B-3216  done
# B-3217  done
# B-3218  done
# B-3219  done
# B-3220  done
# B-3221  done
# B-3222  done
# B-3223  done
# B-3224  done
# B-3225  done
# B-3226  done
# B-3227  done
# B-3228  done
# B-3229  done
# B-3230  done
# B-3231  done
# B-3232  done
# B-3240  done
# B-3241  done
# B-3242  done
# B-3243  done
# B-3244  done
# B-3245  done
# B-3246  done
# B-3247  done
# B-3248  done
# B-3249  done
# B-3250  done
# B-3251  done
# B-3252  done
# B-3253  done
# B-3254  done
# B-3255  done
# B-3256  done
# B-3257  done
# B-3258  done
# B-3259  done
# B-3260  done
# B-3261  done
# B-3262  done
# B-3263  done
# B-3264  done
# B-3265  done
# B-3266  done
# B-3267  done
# B-3268  done
# B-3269  done
# B-3270  done
# B-3271  done
# B-3272  done
# B-3273  done
# B-3274  done
# B-3275  done
# B-3276  done
# B-3277  done
# B-3278  done
# B-3279  done
# B-3280  done
# B-3281  done
# B-3282  done
# B-3283  done
# B-3284  done
# B-3285  done
# B-3286  done
# B-3287  done
# B-3288  done
# B-3289  done
# B-3290  done
# B-3291  done
# B-3292  done
# B-3293  done
# B-3294  done
# B-3295  done
# B-3296  done
# B-3297  done
# B-3298  done
# B-3299  done
# B-3300  done
# B-3301  done
# B-3302  done
# B-3303  done
# B-3304  done
# B-3305  done
# B-3306  done
# B-3307  done
# B-3308  done
# B-3309  done
# B-3310  done
# B-3311  done
# B-3312  done
# B-3313  done
# B-3314  done
# B-3315  done
# B-3316  done
# B-3317  done
# B-3318  done
# B-3319  done
# B-3320  done
# B-3321  done
# B-3322  done
# B-3323  done
# B-3324  done
# B-3325  done
# B-3326  done
# B-3327  done
# B-3328  done
# B-3329  done
# B-3330  done
# B-3331  done
# B-3332  done
# B-3333  done
# B-3334  done
# B-3335  done
# B-3336  done
# B-3337  done
# B-3338  done
# B-3339  done
# B-3340  done
# B-3341  done
# B-3342  done
# B-3343  done
# B-3344  done
# B-3345  done
# B-3346  done
# B-3347  done
# B-3348  done
# B-3349  done
# B-3350  done
# B-3351  done
# B-3352  done
# B-3353  done
# B-3354  done
# B-3355  done
# B-3356  done
# B-3357  done
# B-3358  done
# B-3359  done
# B-3360  done
# B-3361  done
# B-3362  done
# B-3363  done
# B-3364  done
# B-3365  done
# B-3366  done
# B-3367  done
# B-3368  done
# B-3369  done
# B-3370  done
# B-3371  done
# B-3372  done
# B-3373  done
# B-3374  done
# B-3375  done
# B-3376  done
# B-3377  done
# B-3378  done
# B-3379  done
# B-3380  done
# B-3381  done
# B-3382  done
# B-3383  done
# B-3384  done
# B-3385  done
# B-3386  done
# B-3387  done
# B-3388  done
# B-3389  done
# B-3390  done
# B-3391  done
# B-3392  done
# B-3393  done
# B-3394  done
# B-3395  done
# B-3396  done
# B-3397  done
# B-3398  done
# B-3399  done
# B-3400  done
# B-3401  done
# B-3402  done
# B-3403  done
# B-3404  done
# B-3405  done
# B-3406  done
# B-3407  done
# B-3408  done
# B-3409  done
# B-3410  done
# B-3411  done
# B-3412  done
# B-3413  done
# B-3414  done
# B-3415  done
# B-3416  done
# B-3417  done
# B-3418  done
# B-3419  done
# B-3420  done
# B-3421  done
# B-3422  done
# B-3423  done
# B-3424  done
# B-3425  done
# B-3426  done
# B-3427  done
# B-3428  done
# B-3429  done
# B-3430  done
# B-3431  done
# B-3432  done
# B-3433  done
# B-3434  done
# B-3435  done
# B-3436  done
# B-3437  done
# B-3438  done
# B-3439  done
# B-3440  done
# B-3441  done
# B-3442  done
# B-3443  done
# B-3444  done
# B-3445  done
# B-3446  done
# B-3447  done
# B-3448  done
# B-3449  done
# B-3450  done
# B-3451  done
# B-3452  done
# B-3453  done
# B-3454  done
# B-3455  done
# B-3456  done
# B-3457  done
# B-3458  done
# B-3459  done
# B-3460  done
# B-3461  done
# B-3462  done
# B-3463  done
# B-3464  done
# B-3465  done
# B-3466  done
# B-3467  done
# B-3468  done
# B-3469  done
# B-3470  done
# B-3471  done
# B-3472  done
# B-3473  done
# B-3474  done
# B-3475  done
# B-3476  done
# B-3477  done
# B-3478  done
# B-3479  done
# B-3480  done
# B-3481  done
# B-3482  done
# B-3483  done
# B-3484  done
# B-3485  done
# B-3486  done
# B-3487  done
# B-3488  done
# B-3489  done
# B-3490  done
# B-3491  done
# B-3492  done
# B-3493  done
# B-3494  done
# B-3495  done
# B-3496  done
# B-3497  done
# B-3498  done
# B-3499  done
# B-3500  done
# B-3501  done
# B-3502  done
# B-3503  done
# B-3504  done
# B-3505  done
# B-3506  done
# B-3507  done
# B-3508  done
# B-3509  done
# B-3510  done
# B-3511  done
# B-3512  done
# B-3513  done
# B-3514  done
# B-3515  done
# B-3516  done
# B-3517  done
# B-3518  done
# B-3519  done
# B-3520  done
# B-3521  done
# B-3522  done
# B-3523  done
# B-3524  done
# B-3525  done
# B-3526  done
# B-3527  done
# B-3528  done
# B-3529  done
# B-3530  done
# B-3531  done
# B-3532  done
# B-3533  done
# B-3534  done
# B-3535  done
# B-3536  done
# B-3537  done
# B-3538  done
# B-3539  done
# B-3540  done
# B-3541  done
# B-3542  done
# B-3543  done
# B-3544  done
# B-3545  done
# B-3546  done
# B-3547  done
# B-3548  done
# B-3549  done
# B-3550  done
# B-3551  done
# B-3552  done
# B-3553  done
# B-3554  done
# B-3555  done
# B-3556  done
# B-3557  done
# B-3558  done
# B-3559  done
# B-3560  done
# B-3561  done
# B-3562  done
# B-3563  done
# B-3564  done
# B-3565  done
# B-3566  done
# B-3567  done
# B-3568  done
# B-3569  done
# B-3570  done
# B-3571  done
# B-3572  done
# B-3573  done
# B-3574  done
# B-3575  done
# B-3576  done
# B-3577  done
# B-3578  done
# B-3579  done
# B-3580  done
# B-3581  done
# B-3582  done
# B-3583  done
# B-3584  done
# B-3585  done
# B-3586  done
# B-3587  done
# B-3588  done
# B-3589  done
# B-3590  done
# B-3591  done
# B-3592  done
# B-3593  done
# B-3594  done
# B-3595  done
# B-3596  done
# B-3597  done
# B-3598  done
# B-3599  done
# B-3600  done
# B-3601  done
# B-3602  done
# B-3603  done
# B-3604  done
# B-3605  done
# B-3606  done
# B-3607  done
# B-3608  done
# B-3609  done
# B-3610  done
# B-3611  done
# B-3612  done
# B-3613  done
# B-3614  done
# B-3615  done
# B-3616  done
# B-3617  done
# B-3618  done
# B-3619  done
# B-3620  done
# B-3621  done
# B-3622  done
# B-3623  done
# B-3624  done
# B-3625  done
# B-3626  done
# B-3627  done
# B-3628  done
# B-3629  done
# B-3630  done
# B-3631  done
# B-3632  done
# B-3633  done
# B-3634  done
# B-3635  done
# B-3636  done
# B-3637  done
# B-3638  done
# B-3639  done
# B-3640  done
# B-3641  done
# B-3642  done
# B-3643  done
# B-3644  done
# B-3645  done
# B-3646  done
# B-3647  done
# B-3648  done
# B-3649  done
# B-3650  done
# B-3651  done
# B-3652  done
# B-3653  done
# B-3654  done
# B-3655  done
# B-3656  done
# B-3657  done
# B-3658  done
# B-3659  done
# B-3660  done
# B-3661  done
# B-3662  done
# B-3663  done
# B-3664  done
# B-3665  done
# B-3666  done
# B-3667  done
# B-3668  done
# B-3669  done
# B-3670  done
# B-3671  done
# B-3672  done
# B-3673  done
# B-3674  done
# B-3675  done
# B-3676  done
# B-3677  done
# B-3678  done
# B-3679  done
# B-3680  done
# B-3681  done
# B-3682  done
# B-3683  done
# B-3684  done
# B-3685  done
# B-3686  done
# B-3687  done
# B-3688  done
# B-3689  done
# B-3690  done
# B-3691  done
# B-3692  done
# B-3693  done
# B-3694  done
# B-3695  done
# B-3696  done
# B-3697  done
# B-3698  done
# B-3699  done
# B-3700  done
# B-3701  done
# B-3702  done
# B-3703  done
# B-3704  done
# B-3705  done
# B-3706  done
# B-3707  done
# B-3708  done
# B-3709  done
# B-3710  done
# B-3711  done
# B-3712  done
# B-3713  done
# B-3714  done
# B-3715  done
# B-3716  done
# B-3717  done
# B-3718  done
# B-3719  done
# B-3720  done
# B-3721  done
# B-3722  done
# B-3723  done
# B-3724  done
# B-3725  done
# B-3726  done
# B-3727  done
# B-3728  done
# B-3729  done
# B-3730  done
# B-3731  done
# B-3732  done
# B-3733  done
# B-3734  done
# B-3735  done
# B-3736  done
# B-3737  done
# B-3738  done
# B-3739  done
# B-3740  done
# B-3741  done
# B-3742  done
# B-3743  done
# B-3744  done
# B-3745  done
# B-3746  done
# B-3747  done
# B-3748  done
# B-3749  done
# B-3750  done
# B-3751  done
# B-3752  done
# B-3753  done
# B-3754  done
# B-3755  done
# B-3756  done
# B-3757  done
# B-3758  done
# B-3759  done
# B-3760  done
# B-3761  done
# B-3762  done
# B-3763  done
# B-3764  done
# B-3765  done
# B-3766  done
# B-3767  done
# B-3768  done
# B-3769  done
# B-3770  done
# B-3771  done
# B-3772  done
# B-3773  done
# B-3774  done
# B-3775  done
# B-3776  done
# B-3777  done
# B-3778  done
# B-3779  done
# B-3780  done
# B-3781  done
# B-3782  done
# B-3783  done
# B-3784  done
# B-3785  done
# B-3786  done
# B-3787  done
# B-3788  done
# B-3789  done
# B-3790  done
# B-3791  done
# B-3792  done
# B-3793  done
# B-3794  done
# B-3795  done
# B-3796  done
# B-3797  done
# B-3798  done
# B-3799  done
# B-3800  done
# B-3801  done
# B-3802  done
# B-3803  done
# B-3804  done
# B-3805  done
# B-3806  done
# B-3807  done
# B-3808  done
# B-3809  done
# B-3810  done
# B-3811  done
# B-3812  done
# B-3813  done
# B-3814  done
# B-3815  done
# B-3816  done
# B-3817  done
# B-3818  done
# B-3819  done
# B-3820  done
# B-3821  done
# B-3822  done
# B-3823  done
# B-3824  done
# B-3825  done
# B-3826  done
# B-3827  done
# B-3828  done
# B-3829  done
# B-3830  done
# B-3831  done
# B-3832  done
# B-3833  done
# B-3834  done
# B-3835  done
# B-3836  done
# B-3837  done
# B-3838  done
# B-3839  done
# B-3840  done
# B-3841  done
# B-3842  done
# B-3843  done
# B-3844  done
# B-3845  done
# B-3846  done
# B-3847  done
# B-3848  done
# B-3849  done
# B-3850  done
# B-3851  done
# B-3852  done
# B-3853  done
# B-3854  done
# B-3855  done
# B-3856  done
# B-3857  done
# B-3858  done
# B-3859  done
# B-3860  done
# B-3861  done
# B-3862  done
# B-3863  done
# B-3864  done
# B-3865  done
# B-3866  done
# B-3867  done
# B-3868  done
# B-3869  done
# B-3870  done
# B-3871  done
# B-3872  done
# B-3873  done
# B-3874  done
# B-3875  done
# B-3876  done
# B-3877  done
# B-3878  done
# B-3879  done
# B-3880  done
# B-3881  done
# B-3882  done
# B-3883  done
# B-3884  done
# B-3885  done
# B-3886  done
# B-3887  done
# B-3888  done
# B-3889  done
# B-3890  done
# B-3891  done
# B-3892  done
# B-3893  done
# B-3894  done
# B-3895  done
# B-3896  done
# B-3897  done
# B-3898  done
# B-3899  done
# B-3900  done
# B-3901  done
# B-3902  done
# B-3903  done
# B-3904  done
# B-3905  done
# B-3906  done
# B-3907  done
# B-3908  done
# B-3909  done
# B-3910  done
# B-3911  done
# B-3912  done
# B-3913  done
# B-3914  done
# B-3915  done
# B-3916  done
# B-3917  done
# B-3918  done
# B-3919  done
# B-3920  done
# B-3921  done
# B-3922  done
# B-3923  done
# B-3924  done
# B-3925  done
# B-3926  done
# B-3927  done
# B-3928  done
# B-3929  done
# B-3930  done
# B-3931  done
# B-3932  done
# B-3933  done
# B-3934  done
# B-3935  done
# B-3936  done
# B-3937  done
# B-3938  done
# B-3939  done
# B-3940  done
# B-3941  done
# B-3942  done
# B-3943  done
# B-3944  done
# B-3945  done
# B-3946  done
# B-3947  done
# B-3948  done
# B-3949  done
# B-3950  done
# B-3951  done
# B-3952  done
# B-3953  done
# B-3954  done
# B-3955  done
# B-3956  done
# B-3957  done
# B-3958  done
# B-3959  done
# B-3960  done
# B-3961  done
# B-3962  done
# B-3963  done
# B-3964  done
# B-3965  done
# B-3966  done
# B-3967  done
# B-3968  done
# B-3969  done
# B-3970  done
# B-3971  done
# B-3972  done
# B-3973  done
# B-3974  done
# B-3975  done
# B-3976  done
# B-3977  done
# B-3978  done
# B-3979  done
# B-3980  done
# B-3981  done
# B-3982  done
# B-3983  done
# B-3984  done
# B-3985  done
# B-3986  done
# B-3987  done
# B-3988  done
# B-3989  done
# B-3990  done
# B-3991  done
# B-3992  done
# B-3993  done
# B-3994  done
# B-3995  done
# B-3996  done
# B-3997  done
# B-3998  done
# B-3999  done
# B-4000  done
# B-4001  done
# B-4002  done
# B-4003  done
# B-4004  done
# B-4005  done
# B-4006  done
# B-4007  done
# B-4008  done
# B-4009  done
# B-4010  done
# B-4011  done
# B-4012  done
# B-4013  done
# B-4014  done
# B-4015  done
# B-4016  done
# B-4017  done
# B-4018  done
# B-4019  done
# B-4020  done
# B-4021  done
# B-4022  done
# B-4023  done
# B-4024  done
# B-4025  done
# B-4026  done
# B-4027  done
# B-4028  done
# B-4029  done
# B-4030  done
# B-4031  done
# B-4032  done
# B-4033  done
# B-4034  done
# B-4035  done
# B-4036  done
# B-4037  done
# B-4038  done
# B-4039  done
# B-4040  done
# B-4041  done
# B-4042  done
# B-4043  done
# B-4044  done
# B-4045  done
# B-4046  done
# B-4047  done
# B-4048  done
# B-4049  done
# B-4050  done
# B-4051  done
# B-4052  done
# B-4053  done
# B-4054  done
# B-4055  done
# B-4056  done
# B-4057  done
# B-4058  done
# B-4059  done
# B-4060  done
# B-4061  done
# B-4062  done
# B-4063  done
# B-4064  done
# B-4065  done
# B-4066  done
# B-4067  done
# B-4068  done
# B-4069  done
# B-4070  done
# B-4071  done
# B-4072  done
# B-4073  done
# B-4074  done
# B-4075  done
# B-4076  done
# B-4077  done
# B-4078  done
# B-4079  done
# B-4080  done
# B-4081  done
# B-4082  done
# B-4083  done
# B-4084  done
# B-4085  done
# B-4086  done
# B-4087  done
# B-4088  done
# B-4089  done
# B-4090  done
# B-4091  done
# B-4092  done
# B-4093  done
# B-4094  done
# B-4095  done
# B-4096  done
# B-4097  done
# B-4098  done
# B-4099  done
# B-4100  done
# B-4101  done
# B-4102  done
# B-4103  done
# B-4104  done
# B-4105  done
# B-4106  done
# B-4155  done
# B-4156  done
# B-4157  done
# B-4158  done
# B-4159  done
# B-4160  done
# B-4161  done
# B-4162  done
# B-4163  done
# B-4164  done
# B-4165  done
# B-4166  done
# B-4167  done
# B-4168  done
# B-4169  done
# B-4170  done
# B-4171  done
# B-4172  done
# B-4173  done
# B-4174  done
# B-4175  done
# B-4176  done
# B-4177  done
# B-4178  done
# B-4179  done
# B-4180  done
# B-4181  done
# B-4182  done
# B-4183  done
# B-4184  done
# B-4185  done
# B-4186  done
# B-4187  done
# B-4188  done
# B-4189  done
# B-4190  done
# B-4191  done
# B-4192  done
# B-4193  done
# B-4194  done
# B-4195  done
# B-4196  done
# B-4197  done
# B-4198  done
# B-4199  done
# B-4200  done
# B-4201  done
# B-4202  done
# B-4203  done
# B-4204  done
# B-4205  done
# B-4206  done
# B-4207  done
# B-4208  done
# B-4209  done
# B-4210  done
# B-4211  done
# B-4212  done
# B-4213  done
# B-4214  done
# B-4215  done
# B-4216  done
# B-4217  done
# B-4218  done
# B-4219  done
# B-4220  done
# B-4221  done
# B-4222  done
# B-4223  done
# B-4224  done
# B-4225  done
# B-4226  done
# B-4227  done
# B-4228  done
# B-4229  done
# B-4230  done
# B-4231  done
# B-4232  done
# B-4233  done
# B-4234  done
# B-4235  done
# B-4236  done
# B-4237  done
# B-4238  done
# B-4239  done
# B-4240  done
# B-4241  done
# B-4242  done
# B-4243  done
# B-4244  done
# B-4245  done
# B-4246  done
# B-4247  done
# B-4248  done
# B-4249  done
# B-4250  done
# B-4251  done
# B-4252  done
# B-4253  done
# B-4254  done
# B-4255  done
# B-4256  done
# B-4257  done
# B-4258  done
# B-4259  done
# B-4260  done
# B-4261  done
# B-4262  done
# B-4263  done
# B-4264  done
# B-4265  done
# B-4266  done
# B-4267  done
# B-4268  done
# B-4269  done
# B-4270  done
# B-4271  done
# B-4272  done
# B-4273  done
# B-4274  done
# B-4275  done
# B-4276  done
# B-4277  done
# B-4278  done
# B-4279  done
# B-4280  done
# B-4281  done
# B-4282  done
# B-4283  done
# B-4284  done
# B-4285  done
# B-4286  done
# B-4287  done
# B-4288  done
# B-4289  done
# B-4290  done
# B-4291  done
# B-4292  done
# B-4293  done
# B-4294  done
# B-4295  done
# B-4296  done
# B-4297  done
# B-4298  done
# B-4299  done
# B-4300  done
# B-4301  done
# B-4302  done
# B-4303  done
# B-4304  done
# B-4305  done
# B-4306  done
# B-4307  done
# B-4308  done
# B-4309  done
# B-4310  done
# B-4311  done
# B-4312  done
# B-4313  done
# B-4314  done
# B-4315  done
# B-4316  done
# B-4317  done
# B-4318  done
# B-4319  done
# B-4320  done
# B-4321  done
# B-4322  done
# B-4323  done
# B-4324  done
# B-4325  done
# B-4326  done
# B-4327  done
# B-4328  done
# B-4329  done
# B-4330  done
# B-4331  done
# B-4332  done
# B-4333  done
# B-4334  done
# B-4335  done
# B-4336  done
# B-4337  done
# B-4338  done
# B-4339  done
# B-4340  done
# B-4341  done
# B-4342  done
# B-4343  done
# B-4344  done
# B-4345  done
# error in  B-4346
# error in  B-4347
# B-4348  done
# B-4349  done
# B-4350  done
# B-4351  done
# RDKit ERROR: [01:03:14] UFFTYPER: Unrecognized charge state for atom: 4
# B-4352  done
# error in  B-4353
# B-4354  done
# B-4355  done
# B-4356  done
# RDKit WARNING: [01:03:17] UFFTYPER: Warning: hybridization set to SP for atom 0
# RDKit ERROR: [01:03:17] UFFTYPER: Unrecognized charge state for atom: 0
# B-4357  done
# B-4358  done
# B-4359  done
# B-4360  done
# B-4361  done
# B-4362  done
# B-4363  done
# B-4364  done
# B-4365  done
# B-4366  done
# B-4367  done
# B-4368  done
# B-4369  done
# B-4370  done
# B-4371  done
# B-4372  done
# B-4373  done
# B-4374  done
# B-4375  done
# B-4376  done
# B-4377  done
# B-4378  done
# B-4379  done
# B-4380  done
# B-4381  done
# B-4382  done
# B-4383  done
# B-4384  done
# B-4385  done
# B-4386  done
# B-4387  done
# B-4388  done
# B-4389  done
# B-4390  done
# B-4391  done
# B-4392  done
# B-4393  done
# B-4394  done
# B-4395  done
# B-4396  done
# B-4397  done
# B-4398  done
# B-4399  done
# B-4400  done
# B-4401  done
# B-4402  done
# B-4403  done
# B-4404  done
# B-4405  done
# B-4406  done
# B-4407  done
# B-4408  done
# B-4409  done
# B-4410  done
# B-4411  done
# B-4412  done
# B-4413  done
# B-4414  done
# B-4415  done
# B-4416  done
# B-4417  done
# B-4418  done
# B-4419  done
# B-4420  done
# B-4421  done
# B-4422  done
# B-4423  done
# B-4424  done
# B-4425  done
# B-4426  done
# B-4427  done
# B-4428  done
# B-4429  done
# B-4430  done
# B-4431  done
# B-4432  done
# B-4433  done
# B-4434  done
# B-4435  done
# B-4436  done
# B-4437  done
# B-4438  done
# B-4439  done
# B-4440  done
# B-4441  done
# B-4442  done
# B-4443  done
# B-4444  done
# B-4445  done
# B-4446  done
# B-4447  done
# B-4448  done
# B-4449  done
# B-4450  done
# B-4451  done
# B-4452  done
# B-4453  done
# B-4454  done
# B-4455  done
# B-4456  done
# B-4457  done
# B-4458  done
# B-4459  done
# B-4460  done
# B-4461  done
# B-4462  done
# B-4463  done
# B-4464  done
# B-4465  done
# B-4466  done
# B-4467  done
# B-4468  done
# B-4469  done
# B-4470  done
# B-4471  done
# B-4472  done
# B-4473  done
# B-4474  done
# B-4475  done
# B-4476  done
# B-4477  done
# B-4478  done
# B-4479  done
# B-4480  done
# B-4481  done
# B-4482  done
# B-4483  done
# B-4484  done
# B-4485  done
# B-4486  done
# B-4487  done
# B-4488  done
# B-4489  done
# B-4490  done
# B-4491  done
# B-4492  done
# B-4493  done
# B-4494  done
# B-4495  done
# B-4496  done
# B-4497  done
# B-4498  done
# B-4499  done
# B-4500  done
# B-4501  done
# B-4502  done
# B-4503  done
# B-4504  done
# B-4505  done
# B-4506  done
# B-4507  done
# B-4508  done
# B-4509  done
# B-4510  done
# B-4511  done
# B-4512  done
# B-4513  done
# B-4514  done
# B-4515  done
# B-4516  done
# B-4517  done
# B-4518  done
# B-4519  done
# B-4520  done
# B-4521  done
# B-4522  done
# B-4523  done
# B-4524  done
# B-4525  done
# B-4526  done
# B-4527  done
# B-4528  done
# B-4529  done
# B-4530  done
# B-4531  done
# B-4532  done
# B-4533  done
# B-4534  done
# B-4535  done
# B-4536  done
# B-4537  done
# B-4538  done
# B-4539  done
# B-4540  done
# B-4541  done
# B-4542  done
# B-4543  done
# B-4544  done
# B-4545  done
# B-4546  done
# B-4547  done
# B-4548  done
# B-4549  done
# B-4550  done
# B-4551  done
# B-4552  done
# B-4553  done
# B-4554  done
# B-4555  done
# B-4556  done
# B-4557  done
# B-4558  done
# B-4559  done
# B-4560  done
# B-4561  done
# B-4562  done
# B-4563  done
# B-4564  done
# B-4565  done
# B-4566  done
# B-4567  done
# B-4568  done
# B-4569  done
# B-4570  done
# B-4571  done
# B-4572  done
# B-4573  done
# B-4574  done
# B-4575  done
# B-4576  done
# B-4577  done
# B-4578  done
# B-4579  done
# B-4580  done
# B-4581  done
# B-4582  done
# B-4583  done
# B-4584  done
# B-4585  done
# B-4586  done
# B-4587  done
# B-4588  done
# B-4589  done
# B-4590  done
# B-4591  done
# B-4592  done
# B-4593  done
# B-4594  done
# B-4595  done
# B-4596  done
# B-4597  done
# B-4598  done
# B-4599  done
# B-4600  done
# B-4601  done
# B-4602  done
# B-4603  done
# B-4604  done
# B-4605  done
# B-4606  done
# B-4607  done
# B-4608  done
# B-4609  done
# B-4610  done
# B-4611  done
# B-4612  done
# B-4613  done
# B-4614  done
# B-4615  done
# B-4616  done
# B-4617  done
# B-4618  done
# B-4619  done
# B-4620  done
# B-4621  done
# B-4622  done
# B-4623  done
# B-4624  done
# B-4625  done
# B-4626  done
# B-4627  done
# B-4628  done
# B-4629  done
# B-4630  done
# B-4631  done
# B-4632  done
# B-4633  done
# B-4634  done
# B-4635  done
# B-4636  done
# B-4637  done
# B-4638  done
# B-4639  done
# B-4640  done
# B-4641  done
# B-4642  done
# B-4643  done
# B-4644  done
# B-4645  done
# B-4646  done
# B-4647  done
# B-4648  done
# B-4649  done
# B-4650  done
# DONE. time taken =  18210.224217176437

# %%
# remove molecules that did not work

# %%
id_to_remove = []
for i, smile in enumerate (smiles_list):
    if smile in failures:
        id_to_remove.append(i)

new_smiles_list = np.delete(smiles_list, id_to_remove)

# %%
#double check list lengths
print(len(pse_list))
print(len(new_smiles_list))
# Out:
# 4609
# 4609

# %%
# convert to dataframe
def make_dataframe(new_smiles_list, pse_list):
    descriptor_data = { 'Smiles': new_smiles_list, 'Energy':pse_list}
    df = pd.DataFrame(data = descriptor_data)
    df.to_csv('../../Data/Energy/EnergyDataset-B.csv')
    print ('shape: ', df.shape)

# %%
make_dataframe(new_smiles_list, pse_list)
# Out:
# shape:  (4609, 2)
