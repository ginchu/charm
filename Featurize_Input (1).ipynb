# %%
# code to convert SMILES string to bigraph, pull energies as labels
# save and load graphs and energies as input (X) and labels (y)

# %%
import torch
from rdkit import Chem
from dgllife.utils import smiles_to_bigraph
# from dgllife.utils import mol_to_bigraph
from dgl.data.utils import load_graphs
from dgl.data.utils import save_graphs
from dgl.dataloading import GraphDataLoader as gdl
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset

# %%
# class MyDataset():
#     def __init__(self, df:str):
        
#         self.df = pd.read_csv(df)
#         self.name = os.path.basename(df)
        
#         self.bigraph = [] # X
#         self.labels =  np.ndarray([]) # y 
        

#     def featurize_atoms(self, mol):
#     # featurize atoms
#         feats = []
#         for atom in mol.GetAtoms():
#             feats.append(atom.GetAtomicNum())
#         return {'atomic': torch.tensor(feats).reshape(-1, 1).float()}
    
#     def featurize_bonds(self, mol):
#     # featurize bonds
#         feats = []
#         bond_types = [Chem.rdchem.BondType.SINGLE, Chem.rdchem.BondType.DOUBLE,
#                     Chem.rdchem.BondType.TRIPLE, Chem.rdchem.BondType.AROMATIC]
#         for bond in mol.GetBonds():
#             btype = bond_types.index(bond.GetBondType())
#             feats.extend([btype, btype])
#         return {'type': torch.tensor(feats).reshape(-1, 1).float()}
    
#     def process(self):
#     # make bigraphs and labels (energy)
#         self.bigraph = list(self.df['Smiles'].apply(lambda x: smiles_to_bigraph(str(x), node_featurizer=self.featurize_atoms, edge_featurizer=self.featurize_bonds,explicit_hydrogens=True)))
#         self.labels = np.array(self.df["Energy"])
    
#     def __getitem__(self, idx):
#     # get one example by index
#         return self.graphs[idx], self.label[idx]

#     def __len__(self):
#     # number of graphs in dataset
#         return len(self.graphs)
    
#     def save(self, path):
#     # save graphs and labels
#         graph_path = os.path.join(path, self.name + '_dgl_graph.bin')
#         save_graphs(graph_path, self.bigraph, {'labels': torch.tensor(self.labels)})

# %%
from dgl.data import DGLDataset

# %%
class MyDataset(DGLDataset):
    def __init__(self,
                 df:str,
                 url=None,
                 raw_dir=None,
                 save_dir=None,
                 force_reload=False,
                 verbose=False):
        
        self.df = pd.read_csv(df)
        
        self._name = os.path.basename(df)

        self.bigraph = [] # X
        self.labels =  np.ndarray([]) # y 
        
        super(MyDataset, self).__init__(name=os.path.basename(df),
                                        url=url,
                                        raw_dir=raw_dir,
                                        save_dir=save_dir,
                                        force_reload=force_reload,
                                        verbose=verbose)



    def featurize_atoms(self, mol):
    # featurize atoms
        feats = []
        for atom in mol.GetAtoms():
            feats.append(atom.GetAtomicNum())
        return {'atomic': torch.tensor(feats).reshape(-1, 1).float()}
    
    def featurize_bonds(self, mol):
    # featurize bonds
        feats = []
        bond_types = [Chem.rdchem.BondType.SINGLE, Chem.rdchem.BondType.DOUBLE,
                    Chem.rdchem.BondType.TRIPLE, Chem.rdchem.BondType.AROMATIC]
        for bond in mol.GetBonds():
            btype = bond_types.index(bond.GetBondType())
            feats.extend([btype, btype])
        return {'type': torch.tensor(feats).reshape(-1, 1).float()}
    
    def process(self):
    # make bigraphs and labels (energy)
        self.bigraph = list(self.df['Smiles'].apply(lambda x: smiles_to_bigraph(str(x), node_featurizer=self.featurize_atoms, edge_featurizer=self.featurize_bonds,explicit_hydrogens=True)))
        self.labels = np.array(self.df["Energy"])
    
    def __getitem__(self, idx):
    # get one example by index
        return self.graphs[idx], self.label[idx]

    def __len__(self):
    # number of graphs in dataset
        return len(self.graphs)
    
    def save(self):
    # save graphs and labels
        graph_path = os.path.join(self._name + '_dgl_graph.bin')
        save_graphs(graph_path, self.bigraph, {'labels': torch.tensor(self.labels)})
        
    def load(self):
        # load graphs and labels
        graph_path = os.path.join(self._name + '_dgl_graph.bin')
        graphs, label_dict = load_graphs(graph_path)
        labels = label_dict['labels']
        return graphs, labels

# %%
m = MyDataset( '../../Data/Solubility/EnergyDataset-B-Copy1.csv') # file path to csv

# %%
m.process()

# %%
m.save()

# %%
# m.bigraph
# Out:
# [Graph(num_nodes=20, num_edges=38,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=15, num_edges=30,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=30, num_edges=60,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=12, num_edges=22,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=44, num_edges=94,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=15, num_edges=30,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=15, num_edges=30,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=29, num_edges=62,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=14, num_edges=30,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=42, num_edges=88,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=44, num_edges=92,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=84, num_edges=178,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=29, num_edges=60,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=25, num_edges=52,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=26, num_edges=50,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=15, num_edges=30,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=15, num_edges=30,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=24, num_edges=48,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=54, num_edges=110,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=15, num_edges=32,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=12, num_edges=24,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=43, num_edges=92,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=42, num_edges=82,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=26, num_edges=52,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=21, num_edges=42,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=23, num_edges=46,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=19, num_edges=36,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=53, num_edges=112,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=61, num_edges=130,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=23, num_edges=50,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=15, num_edges=28,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=20, num_edges=38,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=14, num_edges=26,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=42, num_edges=90,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=28, num_edges=58,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=51, num_edges=108,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=49, num_edges=104,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=41, num_edges=86,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=26, num_edges=54,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=16, num_edges=30,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=28, num_edges=58,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=64, num_edges=130,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=35, num_edges=72,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=25, num_edges=48,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=15, num_edges=30,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=16, num_edges=30,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=26, num_edges=56,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=48, num_edges=102,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=47, num_edges=98,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=38, num_edges=78,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=14, num_edges=26,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=16, num_edges=30,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=20, num_edges=38,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=19, num_edges=36,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=24, num_edges=46,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=26, num_edges=50,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=19, num_edges=36,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=11, num_edges=20,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=56, num_edges=110,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=12, num_edges=22,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=31, num_edges=66,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=39, num_edges=80,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=24, num_edges=46,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=45, num_edges=92,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=13, num_edges=24,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=9, num_edges=18,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=46, num_edges=98,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=24, num_edges=48,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=24, num_edges=52,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=57, num_edges=120,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=74, num_edges=154,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=44, num_edges=94,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=35, num_edges=74,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=49, num_edges=104,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=31, num_edges=66,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=20, num_edges=40,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=24, num_edges=48,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=27, num_edges=54,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=18, num_edges=38,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=33, num_edges=70,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=36, num_edges=72,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=27, num_edges=54,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=16, num_edges=32,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=20, num_edges=38,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=14, num_edges=26,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=29, num_edges=58,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=16, num_edges=32,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=25, num_edges=50,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=36, num_edges=70,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=26, num_edges=54,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=24, num_edges=48,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=10, num_edges=18,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=22, num_edges=42,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=9, num_edges=16,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=9, num_edges=16,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=56, num_edges=118,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=27, num_edges=62,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=47, num_edges=98,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=37, num_edges=78,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=33, num_edges=68,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=39, num_edges=80,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=10, num_edges=20,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=22, num_edges=42,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=22, num_edges=40,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=16, num_edges=30,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=91, num_edges=194,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=18, num_edges=34,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=8, num_edges=12,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=45, num_edges=92,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=24, num_edges=48,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=23, num_edges=46,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=29, num_edges=58,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=9, num_edges=16,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=5, num_edges=8,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=8, num_edges=14,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=36, num_edges=70,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=54, num_edges=112,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=25, num_edges=48,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=24, num_edges=48,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=22, num_edges=48,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=21, num_edges=42,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=23, num_edges=48,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=21, num_edges=42,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=6, num_edges=10,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=12, num_edges=22,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=10, num_edges=18,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=10, num_edges=18,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=35, num_edges=76,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=9, num_edges=16,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=48, num_edges=102,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=27, num_edges=56,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=14, num_edges=30,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=43, num_edges=90,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=26, num_edges=50,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=45, num_edges=92,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=16, num_edges=34,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=27, num_edges=56,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=16, num_edges=32,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=17, num_edges=32,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=87, num_edges=172,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=20, num_edges=40,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=12, num_edges=22,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=13, num_edges=26,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=118, num_edges=250,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=12, num_edges=20,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=17, num_edges=32,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=27, num_edges=62,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=36, num_edges=74,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=26, num_edges=56,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=40, num_edges=82,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=27, num_edges=56,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=15, num_edges=32,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=22, num_edges=42,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=41, num_edges=86,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=30, num_edges=62,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=26, num_edges=50,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=5, num_edges=8,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=8, num_edges=14,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=6, num_edges=10,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=4, num_edges=6,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=7, num_edges=12,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=3, num_edges=4,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=11, num_edges=20,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=7, num_edges=12,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=6, num_edges=10,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=10, num_edges=18,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=6, num_edges=10,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=6, num_edges=10,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=6, num_edges=10,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=9, num_edges=16,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=7, num_edges=14,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=5, num_edges=8,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=11, num_edges=20,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=5, num_edges=8,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=11, num_edges=20,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=13, num_edges=24,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=5, num_edges=8,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=11, num_edges=22,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=12, num_edges=22,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=16, num_edges=30,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=15, num_edges=28,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=8, num_edges=14,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=5, num_edges=8,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=9, num_edges=16,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=13, num_edges=24,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=8, num_edges=14,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=9, num_edges=16,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=7, num_edges=12,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=19, num_edges=36,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=17, num_edges=32,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=11, num_edges=20,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=12, num_edges=22,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=8, num_edges=14,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=8, num_edges=14,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=8, num_edges=14,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=8, num_edges=14,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=8, num_edges=14,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=8, num_edges=14,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=8, num_edges=14,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=27, num_edges=56,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=26, num_edges=54,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=62, num_edges=132,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=17, num_edges=32,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=16, num_edges=30,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=22, num_edges=48,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=43, num_edges=94,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=46, num_edges=100,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=45, num_edges=94,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=36, num_edges=76,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=26, num_edges=54,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=38, num_edges=82,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=32, num_edges=64,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=33, num_edges=70,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=18, num_edges=34,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=21, num_edges=40,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=17, num_edges=32,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=21, num_edges=40,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=19, num_edges=36,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=62, num_edges=122,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=21, num_edges=40,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=39, num_edges=76,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=23, num_edges=44,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=29, num_edges=56,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=25, num_edges=48,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=47, num_edges=98,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=42, num_edges=82,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=43, num_edges=84,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=65, num_edges=128,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=28, num_edges=56,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=24, num_edges=48,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=24, num_edges=46,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=29, num_edges=56,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=8, num_edges=14,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=11, num_edges=20,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=17, num_edges=32,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=13, num_edges=24,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=16, num_edges=30,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=13, num_edges=24,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=11, num_edges=20,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=14, num_edges=26,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=11, num_edges=20,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=9, num_edges=16,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=10, num_edges=18,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=14, num_edges=26,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=11, num_edges=20,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=8, num_edges=14,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=9, num_edges=16,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=12, num_edges=22,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=10, num_edges=18,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=9, num_edges=16,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=8, num_edges=14,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=8, num_edges=14,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=13, num_edges=24,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=32, num_edges=62,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=20, num_edges=40,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=26, num_edges=54,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=23, num_edges=46,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=33, num_edges=68,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=42, num_edges=86,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=28, num_edges=56,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=32, num_edges=64,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=26, num_edges=54,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=17, num_edges=32,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=54, num_edges=114,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=29, num_edges=60,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=33, num_edges=64,
# ...
#  Graph(num_nodes=9, num_edges=16,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=27, num_edges=52,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=19, num_edges=36,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=12, num_edges=22,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=8, num_edges=14,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=8, num_edges=14,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=46, num_edges=98,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=29, num_edges=60,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=22, num_edges=44,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=27, num_edges=54,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=5, num_edges=8,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=18, num_edges=36,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=51, num_edges=108,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=67, num_edges=140,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=46, num_edges=98,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=39, num_edges=82,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=53, num_edges=110,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=32, num_edges=64,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=22, num_edges=42,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=20, num_edges=40,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=15, num_edges=32,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=14, num_edges=28,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=17, num_edges=34,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=15, num_edges=30,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=26, num_edges=52,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=12, num_edges=22,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=10, num_edges=18,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=13, num_edges=26,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=14, num_edges=26,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=17, num_edges=32,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=29, num_edges=60,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=47, num_edges=102,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=56, num_edges=120,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=27, num_edges=58,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=54, num_edges=110,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=29, num_edges=60,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=17, num_edges=32,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=12, num_edges=22,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=25, num_edges=52,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=20, num_edges=40,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=29, num_edges=58,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=68, num_edges=142,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=40, num_edges=86,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=34, num_edges=74,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=76, num_edges=158,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=52, num_edges=112,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=44, num_edges=92,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=32, num_edges=66,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=34, num_edges=76,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=22, num_edges=46,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=25, num_edges=50,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=46, num_edges=96,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=32, num_edges=68,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=24, num_edges=48,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=20, num_edges=40,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=15, num_edges=30,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=36, num_edges=76,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=51, num_edges=108,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=28, num_edges=58,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=21, num_edges=44,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=34, num_edges=70,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=41, num_edges=82,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=28, num_edges=58,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=44, num_edges=94,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=25, num_edges=54,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=16, num_edges=34,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=22, num_edges=44,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=23, num_edges=46,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=33, num_edges=68,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=57, num_edges=118,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=18, num_edges=38,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=30, num_edges=64,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=19, num_edges=40,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=19, num_edges=38,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=24, num_edges=48,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=24, num_edges=48,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=26, num_edges=54,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=26, num_edges=54,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=18, num_edges=36,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=29, num_edges=60,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=29, num_edges=60,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=18, num_edges=38,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=14, num_edges=26,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=14, num_edges=28,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=18, num_edges=38,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=18, num_edges=36,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=22, num_edges=44,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  Graph(num_nodes=19, num_edges=36,
#        ndata_schemes={'atomic': Scheme(shape=(1,), dtype=torch.float32)}
#        edata_schemes={'type': Scheme(shape=(1,), dtype=torch.float32)}),
#  ...]

# %%
# def load(name, path):
#     # load graphs and labels
#     graph_path = os.path.join(path, name + '_dgl_graph.bin')
#     graphs, label_dict = load_graphs(graph_path)
#     labels = label_dict['labels']
#     return graphs, labels

# %%
# load X and y
X, y = m.load() # name = csv file name, "./graphs" = folder name to store graph data

# %%
# X

# %%
# y

# %%
# split into train and test
X_train, X_test, y_train, y_test = train_test_split(X,y)
# split train into train and validation
X_train, X_val, y_train, y_val = train_test_split(X_train,y_train)

# %%
train_dataset = X_train,y_train
val_dataset = X_val, y_val
test_dataset = X_test, y_test

# %%
train_dataloader = gdl(train_dataset, batch_size=1024, shuffle=True, drop_last=False, num_workers=4)
val_dataloader = gdl(val_dataset, batch_size=1024, shuffle=True, drop_last=False, num_workers=4)
test_dataloader = gdl(test_dataset, batch_size=1024, shuffle=True, drop_last=False, num_workers=4)

# %%
# type(X_train)
# Out:
# list
